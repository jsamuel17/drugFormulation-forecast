# %%
import pandas as pd
import numpy as np
import json
import re
import os

# %%
import json

# Specify the path to your .txt file that contains the JSON
txt_file_path = os.path.join(os.getcwd(), 'data','dailymed_output_686.txt')

# Specify the path where you want to save the .json file
json_file_path = os.path.join(os.getcwd(), 'data','dailymed_output_686.json')

# Read the JSON data from the .txt file
with open(txt_file_path, 'r') as txt_file:
    # Assuming the entire content of the file is a valid JSON string
    json_data = json.load(txt_file)

# Write the JSON data to a .json file
with open(json_file_path, 'w') as json_file:
    json.dump(json_data, json_file, indent=4)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[189], line 10
#       7 json_file_path = os.path.join(os.getcwd(), 'data','dailymed_output_686.json')
#       9 # Read the JSON data from the .txt file
# ---> 10 with open(txt_file_path, 'r') as txt_file:
#      11     # Assuming the entire content of the file is a valid JSON string
#      12     json_data = json.load(txt_file)
#      14 # Write the JSON data to a .json file
#
# File ~/opt/anaconda3/envs/cs5525/lib/python3.9/site-packages/IPython/core/interactiveshell.py:284, in _modified_open(file, *args, **kwargs)
#     277 if file in {0, 1, 2}:
#     278     raise ValueError(
#     279         f"IPython won't let you open fd={file} by default "
#     280         "as it is likely to crash IPython. If you know what you are doing, "
#     281         "you can use builtins' open."
#     282     )
# --> 284 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/samueljon/Desktop/ODP/2024/Winter/drug-exp-forecast/data/dailymed_output_686.txt'

# %%
def clean_object(json):
    def unit_conversion(strength, units):
        # Note: these are the only ones found in data that are relevant to drug_list
        if units == 'g/L':
            return strength, 'mg/mL'
        elif units == 'mg/mm':
            return strength * 1000, 'mg/mL'  # assuming mm == mm^3
        elif units == 'ug/mL':
            return strength / 1000, 'mg/mL'
        elif units == 'g/mL':
            return strength * 1000, 'mg/mL'
        else:
            return strength, units

    def convert_strength(strength):
        match = re.match(r'(\d+\.?\d*)(\S+) in(\d+\.?\d*)(\S+)', strength)
        strength = ""
        units = ""
        if match:
            amount, amount_unit, volume, volume_unit = match.groups()
            strength = float(amount) / float(volume)
            units = f"{amount_unit}/{volume_unit}"
            strength, units = unit_conversion(strength, units)
        return strength, units
    
    if 'ndcs' in json.keys():
        ndcs = re.findall(r'\d{4,5}-\d{3,4}-\d{1,2}', json['ndcs'])
        json['ndcs'] = ndcs
    if 'actives' in json.keys():
        actives_processed = []
        for active in json['actives'].split(' - '):
            active_split = active.split('-')
            if len(active_split) > 2: continue
            ing, strength = active_split
            if len(ing) == 0: continue
            actives_processed.append(((ing.strip().title(),) + convert_strength(strength)))
        json['actives'] = actives_processed

    keep_keys = ['index', 'actives', 'route_type', 'ndcs', 'link', 'drug_name', 'inactive_ndcs']
    inactives = []
    for key, value in json.items():
        if key not in keep_keys:
            name_unii_split = key.split(' (UNII:')
            name = name_unii_split[0].strip().title()
            unii = name_unii_split[1].replace(')', '').strip() if len(name_unii_split) > 1 else ''
            strength, units = convert_strength(value)
            inactives.append((name, unii, strength, units))

    json = {key: json[key] for key in keep_keys if key in json.keys()}
    json['inactives'] = inactives
    return json



def filter_forModeling(data):
    """
    Filters input data to remove items based on specific conditions and provides detailed statistics.
    
    This function applies two filters to each item in the arrays of a given key in the input data:
    1. Removes items where 'route_type' is not 'INTRAVENOUS'.
    2. Removes items that have more than one 'actives'.
    
    After filtering, only items with 'actives', 'route_type', 'drug_name', and 'inactives' keys are retained.

    """
    
    # Statistics variables
    keys_before = len(data)
    item_lengths_before = {key: len(items) for key, items in data.items()}
    
    filtered_data = {}
    stats = {}
    keep_keys = ['drug_name', 'route_type', 'actives', 'inactives']
    
    for key, items in data.items():
        
        # Initial counts
        initial_count = len(items)
        filtered_for_route_type = 0
        filtered_for_actives = 0
        
        # Filter process

        unique_items_set = set()
        for item in items:
#             if item.get('route_type') != 'INTRAVENOUS':
#                 filtered_for_route_type += 1
#                 continue  # Skip this item due to 'route_type'
            if len(item.get('actives', [])) > 1:
                filtered_for_actives += 1
                continue  # Skip this item due to 'actives' count
            
            # Item passes filters, keep only specified keys
            filtered_item = {k: (tuple(v) if isinstance(v, list) else v) for k, v in item.items() if k in keep_keys}
            
            # Convert to a comparable format (tuple) for uniqueness check
            item_tuple = tuple(sorted(filtered_item.items()))
            unique_items_set.add(item_tuple)
            
        
        # Convert unique items back to dictionary format
        unique_filtered_items = [{k: (list(v) if isinstance(v, tuple) and k in ['actives', 'inactives'] else v) for k, v in item} for item in unique_items_set]
            
        # Update filtered data and stats
        if unique_filtered_items:
            filtered_data[key] = unique_filtered_items
            stats[key] = {
                'initial_count': initial_count,
                'filtered_for_route_type': filtered_for_route_type,
                'filtered_for_actives': filtered_for_actives,
                'final_count_before_deduplication': initial_count - filtered_for_route_type - filtered_for_actives,
                'final_count_after_deduplication': len(unique_filtered_items)
            }
    
    # Printing statistics
    print(f'Number of keys before filter: {keys_before}')
    print(f'Number of keys after filter: {len(filtered_data)}')
    
    for key, values in stats.items():
        print(f"\n'{key}': \n\
        Initial count: {values['initial_count']}, \n\
        Filtered for 'route_type': {values['filtered_for_route_type']}, \n\
        Filtered for 'actives': {values['filtered_for_actives']}, \n\
        Final count before deduplication: {values['final_count_before_deduplication']}, \n\
        Final count after deduplication: {values['final_count_after_deduplication']}")
    
    return filtered_data

# %%
path = os.path.join(os.getcwd(), 'data','dailymed_output_686.json')
with open(path) as f:
    data = json.load(f)
    
data = {key.replace('\u200b', '').replace('\xa0', ' ').strip().title(): value for key, value in data.items()}

for drug in data:
    data[drug] = [clean_object(item) for item in data[drug]]

# %%
data['Acetazolamide']
# Out:
# [{'index': 4,
#   'actives': [('Acetazolamide', 100.0, 'mg/mL')],
#   'route_type': 'INTRAVENOUS',
#   'ndcs': ['67457-853-50'],
#   'link': 'https://dailymed.nlm.nih.gov/dailymed/drugInfo.cfm?setid=521838b0-a10d-495f-a014-f9ff25a6b6f3',
#   'drug_name': 'ACETAZOLAMIDE- acetazolamide sodium injection, powder, lyophilized, for solution',
#   'inactive_ndcs': False,
#   'inactives': [('Sodium Hydroxide', '55X04QC32I', '', ''),
#    ('Hydrochloric Acid', 'QTT17582CB', '', '')]},
#  {'index': 4,
#   'actives': [('Acetazolamide', '', '')],
#   'route_type': 'ORAL',
#   'ndcs': ['16729-331-01', '16729-331-17'],
#   'link': 'https://dailymed.nlm.nih.gov/dailymed/drugInfo.cfm?setid=9a368b35-cd51-47ad-83cc-ccc56c4585e8',
#   'drug_name': 'ACETAZOLAMIDE capsule, extended release',
#   'inactive_ndcs': False,
#   'inactives': [('Ethyl Acrylate', '71E6178C9T', '', ''),
#    ('Methacrylate/Methoxy Peg-10 Maleate/Styrene Copolymer',
#     '39DK5WQ2PR',
#     '',
#     ''),
#    ('Cellulose, Microcrystalline', 'OP1R32D61U', '', ''),
#    ('Talc', '7SEV7J4R1U', '', ''),
#    ('Sodium Lauryl Sulfate', '368GB5141J', '', ''),
#    ('Fd&C Blue No. 1', 'H3R47K3TBD', '', ''),
#    ('Fd&C Yellow No. 6', 'H77VEI93A8', '', ''),
#    ('Gelatin', '2G86QN327L', '', ''),
#    ('Ferric Oxide Yellow', 'EX438O2MRT', '', ''),
#    ('Titanium Dioxide', '15FIX9V2JP', '', ''),
#    ('Shellac', '46N107B71O', '', ''),
#    ('Ferrosoferric Oxide', 'XM0M87F357', '', ''),
#    ('Potassium Hydroxide', 'WZH3C48M4T', '', '')]},
#  {'index': 4,
#   'actives': [('Acetazolamide', '', '')],
#   'route_type': 'ORAL',
#   'ndcs': ['62332-349-31', '62332-349-91'],
#   'link': 'https://dailymed.nlm.nih.gov/dailymed/drugInfo.cfm?setid=43231abb-2a5d-44ab-b3e6-7564a1131ac5',
#   'drug_name': 'ACETAZOLAMIDE capsule, extended release',
#   'inactive_ndcs': False,
#   'inactives': [('Microcrystalline Cellulose', 'OP1R32D61U', '', ''),
#    ('Sodium Lauryl Sulfate', '368GB5141J', '', ''),
#    ('Talc', '7SEV7J4R1U', '', ''),
#    ('D&C Red No. 28', '767IP0Y5NH', '', ''),
#    ('D&C Yellow No. 10', '35SW5USQ3G', '', ''),
#    ('Fd&C Red No. 40', 'WZB9127XOA', '', ''),
#    ('Gelatin, Unspecified', '2G86QN327L', '', ''),
#    ('Titanium Dioxide', '15FIX9V2JP', '', ''),
#    ('Shellac', '46N107B71O', '', ''),
#    ('Propylene Glycol', '6DC9Q167V3', '', ''),
#    ('Potassium Hydroxide', 'WZH3C48M4T', '', ''),
#    ('Ferrosoferric Oxide', 'XM0M87F357', '', '')]},
#  {'index': 4,
#   'actives': [('Acetazolamide', '', '')],
#   'route_type': 'ORAL',
#   'ndcs': ['46708-349-31', '46708-349-91'],
#   'link': 'https://dailymed.nlm.nih.gov/dailymed/drugInfo.cfm?setid=d9c1cc75-4e3d-4eaf-87c5-d5942a843818',
#   'drug_name': 'ACETAZOLAMIDE capsule, extended release',
#   'inactive_ndcs': False,
#   'inactives': [('Microcrystalline Cellulose', 'OP1R32D61U', '', ''),
#    ('Sodium Lauryl Sulfate', '368GB5141J', '', ''),
#    ('Talc', '7SEV7J4R1U', '', ''),
#    ('D&C Red No. 28', '767IP0Y5NH', '', ''),
#    ('D&C Yellow No. 10', '35SW5USQ3G', '', ''),
#    ('Fd&C Red No. 40', 'WZB9127XOA', '', ''),
#    ('Gelatin, Unspecified', '2G86QN327L', '', ''),
#    ('Titanium Dioxide', '15FIX9V2JP', '', ''),
#    ('Shellac', '46N107B71O', '', ''),
#    ('Propylene Glycol', '6DC9Q167V3', '', ''),
#    ('Potassium Hydroxide', 'WZH3C48M4T', '', ''),
#    ('Ferrosoferric Oxide', 'XM0M87F357', '', '')]},
#  {'index': 4,
#   'actives': [('Acetazolamide', '', '')],
#   'route_type': 'ORAL',
#   'ndcs': ['62135-612-60'],
#   'link': 'https://dailymed.nlm.nih.gov/dailymed/drugInfo.cfm?setid=e8e48a25-5f6c-4b5a-a5f2-ee87aabea33b',
#   'drug_name': 'ACETAZOLAMIDE capsule, extended release',
#   'inactive_ndcs': False,
#   'inactives': [('Ammonio Methacrylate Copolymer Type A',
#     '8GQS4E66YY',
#     '',
#     ''),
#    ('Ammonio Methacrylate Copolymer Type B', '161H3B14U2', '', ''),
#    ('Fd&C Yellow No. 6', 'H77VEI93A8', '', ''),
#    ('Gelatin', '2G86QN327L', '', ''),
#    ('Cellulose, Microcrystalline', 'OP1R32D61U', '', ''),
#    ('Sodium Lauryl Sulfate', '368GB5141J', '', ''),
#    ('Talc', '7SEV7J4R1U', '', ''),
#    ('Titanium Dioxide', '15FIX9V2JP', '', ''),
#    ('Ferrosoferric Oxide', 'XM0M87F357', '', '')]},
#  {'index': 4,
#   'actives': [('Acetazolamide', '', '')],
#   'route_type': 'ORAL',
#   'ndcs': ['23155-787-01'],
#   'link': 'https://dailymed.nlm.nih.gov/dailymed/drugInfo.cfm?setid=33d912ea-9e1c-49eb-bd93-f0b1b2da67b6',
#   'drug_name': 'ACETAZOLAMIDE capsule, extended release',
#   'inactive_ndcs': False,
#   'inactives': [('Ammonio Methacrylate Copolymer Type A',
#     '8GQS4E66YY',
#     '',
#     ''),
#    ('Ammonio Methacrylate Copolymer Type B', '161H3B14U2', '', ''),
#    ('Fd&C Yellow No. 6', 'H77VEI93A8', '', ''),
#    ('Gelatin', '2G86QN327L', '', ''),
#    ('Cellulose, Microcrystalline', 'OP1R32D61U', '', ''),
#    ('Sodium Lauryl Sulfate', '368GB5141J', '', ''),
#    ('Talc', '7SEV7J4R1U', '', ''),
#    ('Titanium Dioxide', '15FIX9V2JP', '', ''),
#    ('Ferrosoferric Oxide', 'XM0M87F357', '', '')]},
#  {'index': 4,
#   'actives': [('Acetazolamide', '', '')],
#   'route_type': 'ORAL',
#   'ndcs': ['50742-233-01'],
#   'link': 'https://dailymed.nlm.nih.gov/dailymed/drugInfo.cfm?setid=a1f6ed35-9188-4115-8a3c-1ac91c07bf7d',
#   'drug_name': 'ACETAZOLAMIDE capsule, extended release',
#   'inactive_ndcs': False,
#   'inactives': [('Cellulose, Microcrystalline', 'OP1R32D61U', '', ''),
#    ('Hydroxypropyl Cellulose', 'RFW2ET671P', '', ''),
#    ('Starch, Pregelatinized Corn', 'O8232NY3SJ', '', ''),
#    ('Talc', '7SEV7J4R1U', '', ''),
#    ('Gelatin', '2G86QN327L', '', ''),
#    ('Sodium Lauryl Sulfate', '368GB5141J', '', ''),
#    ('Titanium Dioxide', '15FIX9V2JP', '', ''),
#    ('Shellac', '46N107B71O', '', ''),
#    ('Potassium Hydroxide', 'WZH3C48M4T', '', ''),
#    ('Ferrosoferric Oxide', 'XM0M87F357', '', '')]},
#  {'index': 4,
#   'actives': [('Acetazolamide', '', '')],
#   'route_type': 'ORAL',
#   'ndcs': ['29033-030-01'],
#   'link': 'https://dailymed.nlm.nih.gov/dailymed/drugInfo.cfm?setid=58e87a73-0abc-4bd7-9f53-0eace0fe9a11',
#   'drug_name': 'ACETAZOLAMIDE capsule, extended release',
#   'inactive_ndcs': False,
#   'inactives': [('Ferric Oxide Yellow', 'EX438O2MRT', '', ''),
#    ('Ferrosoferric Oxide', 'XM0M87F357', '', ''),
#    ('D&C Yellow No. 10', '35SW5USQ3G', '', ''),
#    ('Fd&C Blue No. 1', 'H3R47K3TBD', '', ''),
#    ('Fd&C Blue No. 2', 'L06K8R7DQK', '', ''),
#    ('Fd&C Red No. 40', 'WZB9127XOA', '', ''),
#    ('Gelatin', '2G86QN327L', '', ''),
#    ('Shellac', '46N107B71O', '', ''),
#    ('Titanium Dioxide', '15FIX9V2JP', '', ''),
#    ('Cellulose, Microcrystalline', 'OP1R32D61U', '', ''),
#    ('Silicon Dioxide', 'ETJ7Z6XBU4', '', ''),
#    ('Hypromelloses', '3NXW29V3WO', '', ''),
#    ('Propylene Glycol', '6DC9Q167V3', '', ''),
#    ('Oleic Acid', '2UMI9U37CP', '', ''),
#    ('Ethylcelluloses', '7Z8S9VYZ4B', '', ''),
#    ('Medium-Chain Triglycerides', 'C9H2L21V7U', '', ''),
#    ('Ammonia', '5138Q19F1X', '', ''),
#    ('Talc', '7SEV7J4R1U', '', '')]},
#  {'index': 4,
#   'actives': [('Acetazolamide', '', '')],
#   'route_type': 'ORAL',
#   'ndcs': ['69367-209-01'],
#   'link': 'https://dailymed.nlm.nih.gov/dailymed/drugInfo.cfm?setid=417b1df2-63bc-473c-9e02-5f93dd45554d',
#   'drug_name': 'ACETAZOLAMIDE capsule, extended release',
#   'inactive_ndcs': False,
#   'inactives': [('Microcrystalline Cellulose', 'OP1R32D61U', '', ''),
#    ('Sodium Lauryl Sulfate', '368GB5141J', '', ''),
#    ('Hydroxypropyl Cellulose, Unspecified', '9XZ8H6N6OH', '', ''),
#    ('Talc', '7SEV7J4R1U', '', ''),
#    ('Fd&C Green No. 3', '3P3ONR6O1S', '', ''),
#    ('Ferrosoferric Oxide', 'XM0M87F357', '', ''),
#    ('Ferric Oxide Yellow', 'EX438O2MRT', '', ''),
#    ('Titanium Dioxide', '15FIX9V2JP', '', ''),
#    ('Gelatin, Unspecified', '2G86QN327L', '', ''),
#    ('Shellac', '46N107B71O', '', ''),
#    ('Propylene Glycol', '6DC9Q167V3', '', ''),
#    ('Potassium Hydroxide', 'WZH3C48M4T', '', '')]},
#  {'index': 4,
#   'actives': [('Acetazolamide', '', '')],
#   'route_type': 'ORAL',
#   'ndcs': ['65841-762-01',
#    '65841-762-05',
#    '65841-762-06',
#    '65841-762-10',
#    '65841-762-16',
#    '65841-762-30'],
#   'link': 'https://dailymed.nlm.nih.gov/dailymed/drugInfo.cfm?setid=2c1d9078-c15f-4dce-bc26-edfa5400fa9b',
#   'drug_name': 'ACETAZOLAMIDE capsule',
#   'inactive_ndcs': False,
#   'inactives': [('Cellulose, Microcrystalline', 'OP1R32D61U', '', ''),
#    ('Ferric Oxide Yellow', 'EX438O2MRT', '', ''),
#    ('Gelatin', '2G86QN327L', '', ''),
#    ('Sodium Lauryl Sulfate', '368GB5141J', '', ''),
#    ('Talc', '7SEV7J4R1U', '', ''),
#    ('Titanium Dioxide', '15FIX9V2JP', '', '')]},
#  {'index': 4,
#   'actives': [('Acetazolamide', '', '')],
#   'route_type': 'ORAL',
#   'ndcs': ['70710-1591-0',
#    '70710-1591-1',
#    '70710-1591-3',
#    '70710-1591-4',
#    '70710-1591-5',
#    '70710-1591-9'],
#   'link': 'https://dailymed.nlm.nih.gov/dailymed/drugInfo.cfm?setid=bf514e99-4958-44a0-a87a-02a950f87e60',
#   'drug_name': 'ACETAZOLAMIDE capsule',
#   'inactive_ndcs': False,
#   'inactives': [('Cellulose, Microcrystalline', 'OP1R32D61U', '', ''),
#    ('Ferric Oxide Yellow', 'EX438O2MRT', '', ''),
#    ('Gelatin', '2G86QN327L', '', ''),
#    ('Sodium Lauryl Sulfate', '368GB5141J', '', ''),
#    ('Talc', '7SEV7J4R1U', '', ''),
#    ('Titanium Dioxide', '15FIX9V2JP', '', '')]},
#  {'index': 4,
#   'actives': [('Acetazolamide', '', '')],
#   'route_type': 'ORAL',
#   'ndcs': ['42571-243-01'],
#   'link': 'https://dailymed.nlm.nih.gov/dailymed/drugInfo.cfm?setid=78f78919-a6ba-4072-bc45-2ab3637ed894',
#   'drug_name': 'ACETAZOLAMIDE EXTENDED-RELEASE capsule',
#   'inactive_ndcs': False,
#   'inactives': [('Hydroxypropyl Cellulose', 'RFW2ET671P', '', ''),
#    ('Talc', '7SEV7J4R1U', '', ''),
#    ('Cellulose, Microcrystalline', 'OP1R32D61U', '', ''),
#    ('Sodium Lauryl Sulfate', '368GB5141J', '', ''),
#    ('D&C Red No. 28', '767IP0Y5NH', '', ''),
#    ('D&C Yellow No. 10', '35SW5USQ3G', '', ''),
#    ('Fd&C Red No. 40', 'WZB9127XOA', '', ''),
#    ('Gelatin', '2G86QN327L', '', ''),
#    ('Titanium Dioxide', '15FIX9V2JP', '', ''),
#    ('Shellac', '46N107B71O', '', ''),
#    ('Alcohol', '3K9958V90M', '', ''),
#    ('Isopropyl Alcohol', 'ND2M416302', '', ''),
#    ('Butyl Alcohol', '8PJ61P6TS3', '', ''),
#    ('Propylene Glycol', '6DC9Q167V3', '', ''),
#    ('Ammonia', '5138Q19F1X', '', ''),
#    ('Ferrosoferric Oxide', 'XM0M87F357', '', ''),
#    ('Potassium Hydroxide', 'WZH3C48M4T', '', '')]},
#  {'index': 4,
#   'actives': [('Acetazolamide', 100.0, 'mg/mL')],
#   'route_type': 'INTRAVENOUS',
#   'ndcs': ['23155-831-31'],
#   'link': 'https://dailymed.nlm.nih.gov/dailymed/drugInfo.cfm?setid=4dd56001-4941-4ff0-9f30-02a1bcc4fe7e',
#   'drug_name': 'ACETAZOLAMIDE injection, powder, lyophilized, for solution',
#   'inactive_ndcs': False,
#   'inactives': [('Sodium Hydroxide', '55X04QC32I', '', ''),
#    ('Hydrochloric Acid', 'QTT17582CB', '', '')]},
#  {'index': 4,
#   'actives': [('Acetazolamide', 100.0, 'mg/mL')],
#   'route_type': 'INTRAVENOUS',
#   'ndcs': ['23155-313-31'],
#   'link': 'https://dailymed.nlm.nih.gov/dailymed/drugInfo.cfm?setid=60f656ff-97b1-4a89-99af-8100483c2bac',
#   'drug_name': 'ACETAZOLAMIDE injection, powder, lyophilized, for solution',
#   'inactive_ndcs': False,
#   'inactives': [('Sodium Hydroxide', '55X04QC32I', '', ''),
#    ('Hydrochloric Acid', 'QTT17582CB', '', '')]},
#  {'index': 4,
#   'actives': [('Acetazolamide', '', '')],
#   'route_type': 'INTRAVENOUS',
#   'ndcs': ['0143-9503-01'],
#   'link': 'https://dailymed.nlm.nih.gov/dailymed/drugInfo.cfm?setid=85975cf0-1286-4af9-ac7f-94bb2483bf09',
#   'drug_name': 'ACETAZOLAMIDE injection, powder, lyophilized, for solution',
#   'inactive_ndcs': False,
#   'inactives': [('Sodium Hydroxide', '55X04QC32I', '', ''),
#    ('Hydrochloric Acid', 'QTT17582CB', '', '')]},
#  {'index': 4,
#   'actives': [('Acetazolamide', '', '')],
#   'route_type': 'INTRAVENOUS',
#   'ndcs': ['0143-9006-01'],
#   'link': 'https://dailymed.nlm.nih.gov/dailymed/drugInfo.cfm?setid=5502e5ba-9b5e-460a-855f-60534b625461',
#   'drug_name': 'ACETAZOLAMIDE injection, powder, lyophilized, for solution',
#   'inactive_ndcs': False,
#   'inactives': [('Sodium Hydroxide', '55X04QC32I', '', ''),
#    ('Hydrochloric Acid', 'QTT17582CB', '', '')]},
#  {'index': 4,
#   'actives': [('Acetazolamide', 100.0, 'mg/mL')],
#   'route_type': 'INTRAVENOUS',
#   'ndcs': ['39822-0190-1'],
#   'link': 'https://dailymed.nlm.nih.gov/dailymed/drugInfo.cfm?setid=a9199d3c-ce52-4db5-aa36-408f4e15e344',
#   'drug_name': 'ACETAZOLAMIDE injection, powder, lyophilized, for solution',
#   'inactive_ndcs': False,
#   'inactives': [('Sodium Hydroxide', '55X04QC32I', '', ''),
#    ('Hydrochloric Acid', 'QTT17582CB', '', '')]},
#  {'index': 4,
#   'actives': [('Acetazolamide', 100.0, 'mg/mL')],
#   'route_type': 'INTRAVENOUS',
#   'ndcs': ['70771-1490-1'],
#   'link': 'https://dailymed.nlm.nih.gov/dailymed/drugInfo.cfm?setid=1269804e-7d32-466c-83e7-99e6ddceb8b2',
#   'drug_name': 'ACETAZOLAMIDE injection, powder, lyophilized, for solution',
#   'inactive_ndcs': False,
#   'inactives': [('Sodium Hydroxide', '55X04QC32I', '', ''),
#    ('Hydrochloric Acid', 'QTT17582CB', '', '')]},
#  {'index': 4,
#   'actives': [('Acetazolamide', 100.0, 'mg/mL')],
#   'route_type': 'INTRAVENOUS',
#   'ndcs': ['68382-076-10'],
#   'link': 'https://dailymed.nlm.nih.gov/dailymed/drugInfo.cfm?setid=490032a5-132f-4870-90ec-6036218cbfe8',
#   'drug_name': 'ACETAZOLAMIDE injection, powder, lyophilized, for solution',
#   'inactive_ndcs': False,
#   'inactives': [('Sodium Hydroxide', '55X04QC32I', '', ''),
#    ('Hydrochloric Acid', 'QTT17582CB', '', '')]},
#  {'index': 4,
#   'actives': [('Acetazolamide', '', '')],
#   'route_type': 'ORAL',
#   'ndcs': ['81005-104-01', '81005-104-10', '81005-105-01', '81005-105-10'],
#   'link': 'https://dailymed.nlm.nih.gov/dailymed/drugInfo.cfm?setid=ddfd44dc-3136-4dda-8ed0-eb2991c2a0b6',
#   'drug_name': 'ACETAZOLAMIDE tablet',
#   'inactive_ndcs': False,
#   'inactives': [('Povidone', 'FZ989GH94E', '', ''),
#    ('Croscarmellose Sodium', 'M28OL1HH48', '', ''),
#    ('Lactose Monohydrate', 'EWQ57Q8I5X', '', ''),
#    ('Cellulose, Microcrystalline', 'OP1R32D61U', '', ''),
#    ('Silicon Dioxide', 'ETJ7Z6XBU4', '', ''),
#    ('Talc', '7SEV7J4R1U', '', ''),
#    ('Magnesium Stearate', '70097M6I30', '', '')]},
#  {'index': 4,
#   'actives': [('Acetazolamide', '', '')],
#   'route_type': 'ORAL',
#   'ndcs': ['72888-047-01', '72888-048-01'],
#   'link': 'https://dailymed.nlm.nih.gov/dailymed/drugInfo.cfm?setid=c24d31f0-a556-4e53-97a9-4e05e28ca40f',
#   'drug_name': 'ACETAZOLAMIDE tablet',
#   'inactive_ndcs': False,
#   'inactives': [('Starch, Corn', 'O8232NY3SJ', '', ''),
#    ('Gelatin, Unspecified', '2G86QN327L', '', ''),
#    ('Glycerin', 'PDC6A3C0OX', '', ''),
#    ('Lactose Monohydrate', 'EWQ57Q8I5X', '', ''),
#    ('Magnesium Stearate', '70097M6I30', '', ''),
#    ('Sodium Starch Glycolate Type A', 'H8AV0SQX4D', '', ''),
#    ('Talc', '7SEV7J4R1U', '', '')]},
#  {'index': 4,
#   'actives': [('Acetazolamide', '', '')],
#   'route_type': 'ORAL',
#   'ndcs': ['27241-132-04', '27241-133-04'],
#   'link': 'https://dailymed.nlm.nih.gov/dailymed/drugInfo.cfm?setid=240ab24b-3124-4805-80c2-36dd1945e3b3',
#   'drug_name': 'ACETAZOLAMIDE tablet',
#   'inactive_ndcs': False,
#   'inactives': [('Starch, Corn', 'O8232NY3SJ', '', ''),
#    ('Dibasic Calcium Phosphate Dihydrate', 'O7TSZ97GEP', '', ''),
#    ('Magnesium Stearate', '70097M6I30', '', ''),
#    ('Water', '059QF0KO0R', '', ''),
#    ('Sodium Starch Glycolate Type A Potato', '5856J3G2A2', '', ''),
#    ('Povidone', 'FZ989GH94E', '', '')]},
#  {'index': 4,
#   'actives': [('Acetazolamide', '', '')],
#   'route_type': 'ORAL',
#   'ndcs': ['70954-033-20', '70954-033-30', '70954-034-20', '70954-034-30'],
#   'link': 'https://dailymed.nlm.nih.gov/dailymed/drugInfo.cfm?setid=bde94a48-05d0-45a0-a589-ec05b7d16532',
#   'drug_name': 'ACETAZOLAMIDE tablet',
#   'inactive_ndcs': False,
#   'inactives': [('
'', '')]},
#  {'index': 4,
#   'actives': [('Acetazolamide', '', '')],
#   'route_type': 'ORAL',
#   'ndcs': ['72789-237-01', '72789-238-01'],
#   'link': 'https://dailymed.nlm.nih.gov/dailymed/drugInfo.cfm?setid=c525ef20-ec9a-4ffd-b5ea-e53c186fe716',
#   'drug_name': 'ACETAZOLAMIDE tablet',
#   'inactive_ndcs': False,
#   'inactives': [('Dibasic Calcium Phosphate Dihydrate', 'O7TSZ97GEP', '', ''),
#    ('Starch, Corn', 'O8232NY3SJ', '', ''),
#    ('Crospovidone', '68401960MK', '', ''),
#    ('Povidone', 'FZ989GH94E', '', ''),
#    ('Magnesium Stearate', '70097M6I30', '', '')]},
#  {'index': 4,
#   'actives': [('Acetazolamide', '', '')],
#   'route_type': 'ORAL',
#   'ndcs': ['72789-045-06', '72789-045-12'],
#   'link': 'https://dailymed.nlm.nih.gov/dailymed/drugInfo.cfm?setid=268db224-d5db-457c-86bc-972c9fe07917',
#   'drug_name': 'ACETAZOLAMIDE tablet',
#   'inactive_ndcs': False,
#   'inactives': [('Lactose Monohydrate', 'EWQ57Q8I5X', '', ''),
#    ('Starch, Corn', 'O8232NY3SJ', '', ''),
#    ('Gelatin', '2G86QN327L', '', ''),
#    ('Glycerin', 'PDC6A3C0OX', '', ''),
#    ('Water', '059QF0KO0R', '', ''),
#    ('Sodium Starch Glycolate Type A Potato', '5856J3G2A2', '', ''),
#    ('Magnesium Stearate', '70097M6I30', '', ''),
#    ('Talc', '7SEV7J4R1U', '', '')]},
#  {'index': 4,
#   'actives': [('Acetazolamide', '', '')],
#   'route_type': 'ORAL',
#   'ndcs': ['55289-720-06', '55289-720-12'],
#   'link': 'https://dailymed.nlm.nih.gov/dailymed/drugInfo.cfm?setid=bd911de5-ea56-41ba-a328-20c8bfe7fe3b',
#   'drug_name': 'ACETAZOLAMIDE tablet',
#   'inactive_ndcs': False,
#   'inactives': [('Starch, Corn', 'O8232NY3SJ', '', ''),
#    ('Lactose Monohydrate', 'EWQ57Q8I5X', '', ''),
#    ('Gelatin, Unspecified', '2G86QN327L', '', ''),
#    ('Glycerin', 'PDC6A3C0OX', '', ''),
#    ('Water', '059QF0KO0R', '', ''),
#    ('Talc', '7SEV7J4R1U', '', ''),
#    ('Sodium Starch Glycolate Type A Potato', '5856J3G2A2', '', ''),
#    ('Magnesium Stearate', '70097M6I30', '', '')]},
#  {'index': 4,
#   'actives': [('Acetazolamide', '', '')],
#   'route_type': 'ORAL',
#   'ndcs': ['54868-1195-0', '54868-1195-2', '54868-1195-3', '54868-1195-4'],
#   'link': 'https://dailymed.nlm.nih.gov/dailymed/drugInfo.cfm?setid=59050278-167e-4641-a253-4e57653f8b6b',
#   'drug_name': 'ACETAZOLAMIDE tablet',
#   'inactive_ndcs': True,
#   'inactives': [('Lactose Monohydrate', 'EWQ57Q8I5X', '', ''),
#    ('Sodium Starch Glycolate Type A Potato', '5856J3G2A2', '', ''),
#    ('Starch, Corn', 'O8232NY3SJ', '', ''),
#    ('Calcium Stearate', '776XM7047L', '', '')]},
#  {'index': 4,
#   'actives': [('Acetazolamide', '', '')],
#   'route_type': 'ORAL',
#   'ndcs': ['71205-308-30', '71205-308-60', '71205-308-90'],
#   'link': 'https://dailymed.nlm.nih.gov/dailymed/drugInfo.cfm?setid=3cdde6aa-c89d-4ea4-aade-6c8b5c3ffdcc',
#   'drug_name': 'ACETAZOLAMIDE tablet',
#   'inactive_ndcs': False,
#   'inactives': [('Lactose Monohydrate', 'EWQ57Q8I5X', '', ''),
#    ('Starch, Corn', 'O8232NY3SJ', '', ''),
#    ('Gelatin, Unspecified', '2G86QN327L', '', ''),
#    ('Glycerin', 'PDC6A3C0OX', '', ''),
#    ('Water', '059QF0KO0R', '', ''),
#    ('Sodium Starch Glycolate Type A Potato', '5856J3G2A2', '', ''),
#    ('Magnesium Stearate', '70097M6I30', '', ''),
#    ('Talc', '7SEV7J4R1U', '', '')]},
#  {'index': 4,
#   'actives': [('Acetazolamide', '', '')],
#   'route_type': 'ORAL',
#   'ndcs': ['67296-0801-1'],
#   'link': 'https://dailymed.nlm.nih.gov/dailymed/drugInfo.cfm?setid=6972d9c1-36ec-4246-bf7b-13206d5952c3',
#   'drug_name': 'ACETAZOLAMIDE tablet',
#   'inactive_ndcs': True,
#   'inactives': [('Lactose Monohydrate', 'EWQ57Q8I5X', '', ''),
#    ('Sodium Starch Glycolate Type A Potato', '5856J3G2A2', '', ''),
#    ('Starch, Corn', 'O8232NY3SJ', '', ''),
#    ('Calcium Stearate', '776XM7047L', '', '')]}]

# %%
filtered_data = filter_forModeling(data)
print(f'\n\nTotal number of API-Excp mixture data entries for modeling: {sum([len(v) for k,v in filtered_data.items()])}')
# Out:
# Number of keys before filter: 711
# Number of keys after filter: 586
#
# 'Abacavir Sulfate':
#         Initial count: 31,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 14,
#         Final count before deduplication: 17,
#         Final count after deduplication: 12
#
# 'Acamprosate Calcium':
#         Initial count: 8,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 8,
#         Final count after deduplication: 6
#
# 'Acetaminophen':
#         Initial count: 4960,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 3534,
#         Final count before deduplication: 1426,
#         Final count after deduplication: 1089
#
# 'Acetazolamide':
#         Initial count: 64,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 64,
#         Final count after deduplication: 33
#
# 'Acetylcholine Chloride':
#         Initial count: 34,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 28,
#         Final count before deduplication: 6,
#         Final count after deduplication: 5
#
# 'Acetylcysteine':
#         Initial count: 24,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 2,
#         Final count before deduplication: 22,
#         Final count after deduplication: 16
#
# 'Acitretin':
#         Initial count: 8,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 8,
#         Final count after deduplication: 8
#
# 'Acyclovir':
#         Initial count: 280,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 1,
#         Final count before deduplication: 279,
#         Final count after deduplication: 108
#
# 'Adefovir Dipivoxil':
#         Initial count: 3,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 3,
#         Final count after deduplication: 3
#
# 'Adenosine':
#         Initial count: 928,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 724,
#         Final count before deduplication: 204,
#         Final count after deduplication: 180
#
# 'Methylphenidate Hydrochloride':
#         Initial count: 113,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 113,
#         Final count after deduplication: 90
#
# 'Albendazole':
#         Initial count: 20,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 20,
#         Final count after deduplication: 11
#
# 'Albuterol':
#         Initial count: 178,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 24,
#         Final count before deduplication: 154,
#         Final count after deduplication: 65
#
# 'Alendronate':
#         Initial count: 48,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 2,
#         Final count before deduplication: 46,
#         Final count after deduplication: 20
#
# 'Alfentanil':
#         Initial count: 2,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 2,
#         Final count after deduplication: 2
#
# 'Alfuzosin Hydrochloride':
#         Initial count: 29,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 29,
#         Final count after deduplication: 17
#
# 'Aliskiren':
#         Initial count: 7,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 2,
#         Final count before deduplication: 5,
#         Final count after deduplication: 5
#
# 'Allopurinol':
#         Initial count: 145,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 145,
#         Final count after deduplication: 50
#
# 'Alogliptin':
#         Initial count: 11,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 5,
#         Final count before deduplication: 6,
#         Final count after deduplication: 3
#
# 'Alosetron':
#         Initial count: 9,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 9,
#         Final count after deduplication: 7
#
# 'Alprazolam':
#         Initial count: 188,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 188,
#         Final count after deduplication: 88
#
# 'Alvimopan':
#         Initial count: 5,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 5,
#         Final count after deduplication: 4
#
# 'Amantadine':
#         Initial count: 66,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 66,
#         Final count after deduplication: 42
#
# 'Ambrisentan':
#         Initial count: 11,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 11,
#         Final count after deduplication: 9
#
# 'Amiloride Hydrochloride':
#         Initial count: 10,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 3,
#         Final count before deduplication: 7,
#         Final count after deduplication: 6
#
# 'Aminocaproic Acid':
#         Initial count: 59,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 26,
#         Final count before deduplication: 33,
#         Final count after deduplication: 22
#
# 'Amiodarone Hydrochloride':
#         Initial count: 60,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 60,
#         Final count after deduplication: 27
#
# 'Amitriptyline Hydrochloride':
#         Initial count: 192,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 3,
#         Final count before deduplication: 189,
#         Final count after deduplication: 80
#
# 'Amlodipine':
#         Initial count: 332,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 141,
#         Final count before deduplication: 191,
#         Final count after deduplication: 63
#
# 'Amphetamine':
#         Initial count: 131,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 102,
#         Final count before deduplication: 29,
#         Final count after deduplication: 25
#
# 'Anagrelide Hydrochloride':
#         Initial count: 5,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 5,
#         Final count after deduplication: 5
#
# 'Anastrozole':
#         Initial count: 48,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 1,
#         Final count before deduplication: 47,
#         Final count after deduplication: 24
#
# 'Apixaban':
#         Initial count: 12,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 12,
#         Final count after deduplication: 5
#
# 'Apomorphine Hydrochloride':
#         Initial count: 7,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 4,
#         Final count before deduplication: 3,
#         Final count after deduplication: 3
#
# 'Aprepitant':
#         Initial count: 8,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 8,
#         Final count after deduplication: 8
#
# 'Arformoterol Tartrate':
#         Initial count: 9,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 9,
#         Final count after deduplication: 8
#
# 'Argatroban':
#         Initial count: 16,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 16,
#         Final count after deduplication: 11
#
# 'Aripiprazole':
#         Initial count: 137,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 137,
#         Final count after deduplication: 82
#
# 'Armodafinil':
#         Initial count: 20,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 20,
#         Final count after deduplication: 10
#
# 'Asenapine':
#         Initial count: 10,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 10,
#         Final count after deduplication: 10
#
# 'Atazanavir':
#         Initial count: 14,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 1,
#         Final count before deduplication: 13,
#         Final count after deduplication: 10
#
# 'Atenolol':
#         Initial count: 187,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 18,
#         Final count before deduplication: 169,
#         Final count after deduplication: 39
#
# 'Atomoxetine':
#         Initial count: 47,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 47,
#         Final count after deduplication: 29
#
# 'Atorvastatin Calcium':
#         Initial count: 378,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 17,
#         Final count before deduplication: 361,
#         Final count after deduplication: 115
#
# 'Atovaquone':
#         Initial count: 35,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 17,
#         Final count before deduplication: 18,
#         Final count after deduplication: 13
#
# 'Atropine Sulfate':
#         Initial count: 171,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 112,
#         Final count before deduplication: 59,
#         Final count after deduplication: 36
#
# 'Auranofin':
#         Initial count: 2,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 2,
#         Final count after deduplication: 1
#
# 'Avanafil':
#         Initial count: 1,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 1,
#         Final count after deduplication: 1
#
# 'Azacitidine':
#         Initial count: 26,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 26,
#         Final count after deduplication: 12
#
# 'Azathioprine':
#         Initial count: 26,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 26,
#         Final count after deduplication: 13
#
# 'Azelastine Hydrochloride':
#         Initial count: 44,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 7,
#         Final count before deduplication: 37,
#         Final count after deduplication: 27
#
# 'Baclofen':
#         Initial count: 171,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 171,
#         Final count after deduplication: 61
#
# 'Baloxavir Marboxil':
#         Initial count: 3,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 3,
#         Final count after deduplication: 3
#
# 'Balsalazide Disodium':
#         Initial count: 11,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 11,
#         Final count after deduplication: 6
#
# 'Bempedoic Acid':
#         Initial count: 2,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 1,
#         Final count before deduplication: 1,
#         Final count after deduplication: 1
#
# 'Benazepril Hydrochloride':
#         Initial count: 168,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 72,
#         Final count before deduplication: 96,
#         Final count after deduplication: 43
#
# 'Bendamustine Hydrochloride':
#         Initial count: 11,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 11,
#         Final count after deduplication: 9
#
# 'Benzonatate':
#         Initial count: 185,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 185,
#         Final count after deduplication: 46
#
# 'Benztropine Mesylate':
#         Initial count: 61,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 61,
#         Final count after deduplication: 25
#
# 'Betaxolol Hydrochloride':
#         Initial count: 11,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 11,
#         Final count after deduplication: 10
#
# 'Bethanechol Chloride':
#         Initial count: 18,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 18,
#         Final count after deduplication: 9
#
# 'Bexarotene':
#         Initial count: 13,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 13,
#         Final count after deduplication: 12
#
# 'Bicalutamide':
#         Initial count: 15,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 15,
#         Final count after deduplication: 12
#
# 'Bisacodyl':
#         Initial count: 182,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 1,
#         Final count before deduplication: 181,
#         Final count after deduplication: 125
#
# 'Bisoprolol Fumarate':
#         Initial count: 60,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 30,
#         Final count before deduplication: 30,
#         Final count after deduplication: 22
#
# 'Bortezomib':
#         Initial count: 27,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 27,
#         Final count after deduplication: 10
#
# 'Bosentan':
#         Initial count: 6,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 6,
#         Final count after deduplication: 6
#
# 'Bosutinib':
#         Initial count: 2,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 2,
#         Final count after deduplication: 2
#
# 'Brexpiprazole':
#         Initial count: 5,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 5,
#         Final count after deduplication: 5
#
# 'Bumetanide':
#         Initial count: 53,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 53,
#         Final count after deduplication: 25
#
# 'Bupivacaine Hydrochloride':
#         Initial count: 117,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 22,
#         Final count before deduplication: 95,
#         Final count after deduplication: 85
#
# 'Bupropion':
#         Initial count: 355,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 3,
#         Final count before deduplication: 352,
#         Final count after deduplication: 182
#
# 'Buspirone Hydrochloride':
#         Initial count: 216,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 216,
#         Final count after deduplication: 43
#
# 'Busulfan':
#         Initial count: 15,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 15,
#         Final count after deduplication: 8
#
# 'Cabozantinib':
#         Initial count: 2,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 2,
#         Final count after deduplication: 2
#
# 'Canagliflozin':
#         Initial count: 7,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 1,
#         Final count before deduplication: 6,
#         Final count after deduplication: 2
#
# 'Candesartan Cilexetil':
#         Initial count: 29,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 9,
#         Final count before deduplication: 20,
#         Final count after deduplication: 14
#
# 'Capecitabine':
#         Initial count: 28,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 28,
#         Final count after deduplication: 20
#
# 'Captopril':
#         Initial count: 37,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 2,
#         Final count before deduplication: 35,
#         Final count after deduplication: 15
#
# 'Carbamazepine':
#         Initial count: 110,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 110,
#         Final count after deduplication: 57
#
# 'Carbidopa':
#         Initial count: 82,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 70,
#         Final count before deduplication: 12,
#         Final count after deduplication: 9
#
# 'Carbinoxamine Maleate':
#         Initial count: 6,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 6,
#         Final count after deduplication: 6
#
# 'Carboplatin':
#         Initial count: 17,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 17,
#         Final count after deduplication: 7
#
# 'Carglumic Acid':
#         Initial count: 4,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 4,
#         Final count after deduplication: 4
#
# 'Cariprazine':
#         Initial count: 2,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 2,
#         Final count after deduplication: 2
#
# 'Carisoprodol':
#         Initial count: 120,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 1,
#         Final count before deduplication: 119,
#         Final count after deduplication: 52
#
# 'Carmustine':
#         Initial count: 15,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 15,
#         Final count after deduplication: 6
#
# 'Carvedilol':
#         Initial count: 174,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 174,
#         Final count after deduplication: 63
#
# 'Celecoxib':
#         Initial count: 183,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 1,
#         Final count before deduplication: 182,
#         Final count after deduplication: 90
#
# 'Cetirizine':
#         Initial count: 528,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 46,
#         Final count before deduplication: 482,
#         Final count after deduplication: 270
#
# 'Cevimeline Hydrochloride':
#         Initial count: 15,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 15,
#         Final count after deduplication: 12
#
# 'Chlorambucil':
#         Initial count: 2,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 2,
#         Final count after deduplication: 1
#
# 'Chlordiazepoxide Hydrochloride':
#         Initial count: 57,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 29,
#         Final count before deduplication: 28,
#         Final count after deduplication: 16
#
# 'Chlorothiazide Sodium':
#         Initial count: 9,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 9,
#         Final count after deduplication: 5
#
# 'Chlorpheniramine Maleate':
#         Initial count: 424,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 368,
#         Final count before deduplication: 56,
#         Final count after deduplication: 37
#
# 'Chlorpromazine Hydrochloride':
#         Initial count: 50,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 50,
#         Final count after deduplication: 23
#
# 'Chlorthalidone':
#         Initial count: 93,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 18,
#         Final count before deduplication: 75,
#         Final count after deduplication: 33
#
# 'Chlorzoxazone':
#         Initial count: 45,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 45,
#         Final count after deduplication: 20
#
# 'Cilostazol':
#         Initial count: 17,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 17,
#         Final count after deduplication: 12
#
# 'Cimetidine':
#         Initial count: 37,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 2,
#         Final count before deduplication: 35,
#         Final count after deduplication: 28
#
# 'Cinacalcet Hydrochloride':
#         Initial count: 30,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 30,
#         Final count after deduplication: 16
#
# 'Ciprofloxacin':
#         Initial count: 330,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 21,
#         Final count before deduplication: 309,
#         Final count after deduplication: 111
#
# 'Cisatracurium Besylate':
#         Initial count: 25,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 25,
#         Final count after deduplication: 11
#
# 'Cisplatin':
#         Initial count: 14,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 14,
#         Final count after deduplication: 9
#
# 'Citalopram Hydrobromide':
#         Initial count: 166,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 166,
#         Final count after deduplication: 77
#
# 'Cladribine':
#         Initial count: 5,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 5,
#         Final count after deduplication: 4
#
# 'Clevidipine':
#         Initial count: 2,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 2,
#         Final count after deduplication: 2
#
# 'Clobazam':
#         Initial count: 30,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 30,
#         Final count after deduplication: 23
#
# 'Clofarabine':
#         Initial count: 13,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 13,
#         Final count after deduplication: 7
#
# 'Clomiphene Citrate':
#         Initial count: 12,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 12,
#         Final count after deduplication: 4
#
# 'Clomipramine Hydrochloride':
#         Initial count: 32,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 32,
#         Final count after deduplication: 15
#
# 'Clonazepam':
#         Initial count: 151,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 151,
#         Final count after deduplication: 57
#
# 'Clonidine':
#         Initial count: 172,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 172,
#         Final count after deduplication: 64
#
# 'Clopidogrel Bisulfate':
#         Initial count: 105,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 105,
#         Final count after deduplication: 56
#
# 'Clorazepate Dipotassium':
#         Initial count: 13,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 13,
#         Final count after deduplication: 11
#
# 'Clotrimazole':
#         Initial count: 344,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 41,
#         Final count before deduplication: 303,
#         Final count after deduplication: 233
#
# 'Clozapine':
#         Initial count: 23,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 23,
#         Final count after deduplication: 12
#
# 'Crizotinib':
#         Initial count: 1,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 1,
#         Final count after deduplication: 1
#
# 'Cromolyn Sodium':
#         Initial count: 29,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 29,
#         Final count after deduplication: 16
#
# 'Cyclobenzaprine Hydrochloride':
#         Initial count: 316,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 1,
#         Final count before deduplication: 315,
#         Final count after deduplication: 130
#
# 'Cyclophosphamide':
#         Initial count: 29,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 29,
#         Final count after deduplication: 13
#
# 'Cyproheptadine Hydrochloride':
#         Initial count: 42,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 42,
#         Final count after deduplication: 17
#
# 'Cysteamine Bitartrate':
#         Initial count: 2,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 2,
#         Final count after deduplication: 2
#
# 'Dabigatran Etexilate':
#         Initial count: 10,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 10,
#         Final count after deduplication: 7
#
# 'Dacarbazine':
#         Initial count: 3,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 3,
#         Final count after deduplication: 3
#
# 'Dacomitinib':
#         Initial count: 2,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 2,
#         Final count after deduplication: 1
#
# 'Dalfampridine':
#         Initial count: 10,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 10,
#         Final count after deduplication: 7
#
# 'Dantrolene':
#         Initial count: 25,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 25,
#         Final count after deduplication: 13
#
# 'Dapagliflozin':
#         Initial count: 10,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 3,
#         Final count before deduplication: 7,
#         Final count after deduplication: 5
#
# 'Dapsone':
#         Initial count: 39,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 8,
#         Final count before deduplication: 31,
#         Final count after deduplication: 21
#
# 'Darifenacin':
#         Initial count: 12,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 12,
#         Final count after deduplication: 10
#
# 'Dasatinib':
#         Initial count: 2,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 2,
#         Final count after deduplication: 2
#
# 'Decitabine':
#         Initial count: 30,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 1,
#         Final count before deduplication: 29,
#         Final count after deduplication: 13
#
# 'Deferasirox':
#         Initial count: 34,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 34,
#         Final count after deduplication: 29
#
# 'Deferiprone':
#         Initial count: 8,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 8,
#         Final count after deduplication: 7
#
# 'Deferoxamine Mesylate':
#         Initial count: 8,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 8,
#         Final count after deduplication: 4
#
# 'Desipramine Hydrochloride':
#         Initial count: 17,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 17,
#         Final count after deduplication: 13
#
# 'Desloratadine':
#         Initial count: 16,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 2,
#         Final count before deduplication: 14,
#         Final count after deduplication: 9
#
# 'Desvenlafaxine':
#         Initial count: 43,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 43,
#         Final count after deduplication: 27
#
# 'Dexlansoprazole':
#         Initial count: 15,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 15,
#         Final count after deduplication: 12
#
# 'Dexmedetomidine':
#         Initial count: 46,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 46,
#         Final count after deduplication: 28
#
# 'Dexmethylphenidate Hydrochloride':
#         Initial count: 53,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 1,
#         Final count before deduplication: 52,
#         Final count after deduplication: 37
#
# 'Dexrazoxane Hydrochloride':
#         Initial count: 9,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 9,
#         Final count after deduplication: 5
#
# 'Dextroamphetamine Sulfate':
#         Initial count: 133,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 102,
#         Final count before deduplication: 31,
#         Final count after deduplication: 20
#
# 'Diazepam':
#         Initial count: 158,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 158,
#         Final count after deduplication: 66
#
# 'Diazoxide':
#         Initial count: 4,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 4,
#         Final count after deduplication: 4
#
# 'Dichlorphenamide':
#         Initial count: 4,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 4,
#         Final count after deduplication: 3
#
# 'Diclofenac':
#         Initial count: 572,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 33,
#         Final count before deduplication: 539,
#         Final count after deduplication: 265
#
# 'Dicyclomine Hydrochloride':
#         Initial count: 145,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 145,
#         Final count after deduplication: 58
#
# 'Didanosine':
#         Initial count: 2,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 2,
#         Final count after deduplication: 2
#
# 'Diflunisal':
#         Initial count: 8,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 8,
#         Final count after deduplication: 6
#
# 'Diltiazem':
#         Initial count: 161,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 161,
#         Final count after deduplication: 94
#
# 'Dimenhydrinate':
#         Initial count: 36,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 36,
#         Final count after deduplication: 23
#
# 'Diphenhydramine':
#         Initial count: 1610,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 653,
#         Final count before deduplication: 957,
#         Final count after deduplication: 679
#
# 'Dimercaprol':
#         Initial count: 2,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 2,
#         Final count after deduplication: 2
#
# 'Diphenhydramine Hydrochloride':
#         Initial count: 1554,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 600,
#         Final count before deduplication: 954,
#         Final count after deduplication: 676
#
# 'Dipyridamole':
#         Initial count: 28,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 14,
#         Final count before deduplication: 14,
#         Final count after deduplication: 14
#
# 'Disopyramide Phosphate':
#         Initial count: 9,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 9,
#         Final count after deduplication: 9
#
# 'Disulfiram':
#         Initial count: 7,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 7,
#         Final count after deduplication: 6
#
# 'Divalproex Sodium':
#         Initial count: 178,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 178,
#         Final count after deduplication: 46
#
# 'Dobutamine Hydrochloride':
#         Initial count: 13,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 13,
#         Final count after deduplication: 11
#
# 'Docusate':
#         Initial count: 594,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 221,
#         Final count before deduplication: 373,
#         Final count after deduplication: 214
#
# 'Docusate Calcium':
#         Initial count: 39,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 19,
#         Final count before deduplication: 20,
#         Final count after deduplication: 17
#
# 'Dofetilide':
#         Initial count: 18,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 18,
#         Final count after deduplication: 10
#
# 'Dolutegravir':
#         Initial count: 8,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 3,
#         Final count before deduplication: 5,
#         Final count after deduplication: 4
#
# 'Donepezil Hydrochloride':
#         Initial count: 103,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 2,
#         Final count before deduplication: 101,
#         Final count after deduplication: 81
#
# 'Doravirine':
#         Initial count: 4,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 1,
#         Final count before deduplication: 3,
#         Final count after deduplication: 1
#
# 'Doxapram Hydrochloride':
#         Initial count: 2,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 2,
#         Final count after deduplication: 2
#
# 'Doxazosin Mesylate':
#         Initial count: 79,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 79,
#         Final count after deduplication: 38
#
# 'Doxepin Hydrochloride':
#         Initial count: 121,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 121,
#         Final count after deduplication: 67
#
# 'Doxylamine Succinate':
#         Initial count: 802,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 760,
#         Final count before deduplication: 42,
#         Final count after deduplication: 27
#
# 'Dronabinol':
#         Initial count: 19,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 19,
#         Final count after deduplication: 10
#
# 'Dronedarone':
#         Initial count: 3,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 3,
#         Final count after deduplication: 2
#
# 'Droxidopa':
#         Initial count: 17,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 17,
#         Final count after deduplication: 13
#
# 'Duloxetine':
#         Initial count: 183,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 183,
#         Final count after deduplication: 92
#
# 'Duvelisib':
#         Initial count: 2,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 2,
#         Final count after deduplication: 2
#
# 'Efavirenz':
#         Initial count: 27,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 16,
#         Final count before deduplication: 11,
#         Final count after deduplication: 7
#
# 'Elagolix':
#         Initial count: 2,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 1,
#         Final count before deduplication: 1,
#         Final count after deduplication: 1
#
# 'Eletriptan':
#         Initial count: 15,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 15,
#         Final count after deduplication: 12
#
# 'Eltrombopag':
#         Initial count: 2,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 2,
#         Final count after deduplication: 2
#
# 'Empagliflozin':
#         Initial count: 11,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 4,
#         Final count before deduplication: 7,
#         Final count after deduplication: 1
#
# 'Emtricitabine':
#         Initial count: 83,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 76,
#         Final count before deduplication: 7,
#         Final count after deduplication: 5
#
# 'Enalapril':
#         Initial count: 129,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 6,
#         Final count before deduplication: 123,
#         Final count after deduplication: 51
#
# 'Encorafenib':
#         Initial count: 2,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 2,
#         Final count after deduplication: 1
#
# 'Entacapone':
#         Initial count: 27,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 6,
#         Final count before deduplication: 21,
#         Final count after deduplication: 13
#
# 'Ephedrine Sulfate':
#         Initial count: 29,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 29,
#         Final count after deduplication: 14
#
# 'Epinephrine':
#         Initial count: 461,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 351,
#         Final count before deduplication: 110,
#         Final count after deduplication: 79
#
# 'Erlotinib':
#         Initial count: 16,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 16,
#         Final count after deduplication: 12
#
# 'Escitalopram Oxalate':
#         Initial count: 190,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 190,
#         Final count after deduplication: 53
#
# 'Esketamine':
#         Initial count: 2,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 2,
#         Final count after deduplication: 2
#
# 'Eslicarbazepine Acetate':
#         Initial count: 2,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 2,
#         Final count after deduplication: 2
#
# 'Esmolol Hydrochloride':
#         Initial count: 26,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 26,
#         Final count after deduplication: 19
#
# 'Esomeprazole':
#         Initial count: 226,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 6,
#         Final count before deduplication: 220,
#         Final count after deduplication: 138
#
# 'Estazolam':
#         Initial count: 5,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 5,
#         Final count after deduplication: 4
#
# 'Eszopiclone':
#         Initial count: 95,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 95,
#         Final count after deduplication: 45
#
# 'Ethacrynate Sodium':
#         Initial count: 9,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 9,
#         Final count after deduplication: 7
#
# 'Ethambutol Hydrochloride':
#         Initial count: 18,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 18,
#         Final count after deduplication: 12
#
# 'Ethosuximide':
#         Initial count: 15,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 15,
#         Final count after deduplication: 14
#
# 'Etodolac':
#         Initial count: 97,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 1,
#         Final count before deduplication: 96,
#         Final count after deduplication: 59
#
# 'Etomidate':
#         Initial count: 21,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 21,
#         Final count after deduplication: 11
#
# 'Etravirine':
#         Initial count: 8,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 8,
#         Final count after deduplication: 5
#
# 'Ezetimibe':
#         Initial count: 64,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 21,
#         Final count before deduplication: 43,
#         Final count after deduplication: 20
#
# 'Famciclovir':
#         Initial count: 15,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 15,
#         Final count after deduplication: 10
#
# 'Famotidine':
#         Initial count: 388,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 49,
#         Final count before deduplication: 339,
#         Final count after deduplication: 176
#
# 'Febuxostat':
#         Initial count: 27,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 27,
#         Final count after deduplication: 15
#
# 'Felbamate':
#         Initial count: 19,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 19,
#         Final count after deduplication: 12
#
# 'Felodipine':
#         Initial count: 40,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 40,
#         Final count after deduplication: 25
#
# 'Fenofibrate':
#         Initial count: 183,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 183,
#         Final count after deduplication: 69
#
# 'Fenofibric Acid':
#         Initial count: 22,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 22,
#         Final count after deduplication: 18
#
# 'Fentanyl':
#         Initial count: 63,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 6,
#         Final count before deduplication: 57,
#         Final count after deduplication: 46
#
# 'Fesoterodine Fumarate':
#         Initial count: 17,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 17,
#         Final count after deduplication: 11
#
# 'Fexofenadine Hydrochloride':
#         Initial count: 308,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 52,
#         Final count before deduplication: 256,
#         Final count after deduplication: 145
#
# 'Fingolimod':
#         Initial count: 17,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 17,
#         Final count after deduplication: 15
#
# 'Flavoxate Hydrochloride':
#         Initial count: 5,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 5,
#         Final count after deduplication: 4
#
# 'Flecainide Acetate':
#         Initial count: 29,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 29,
#         Final count after deduplication: 10
#
# 'Floxuridine':
#         Initial count: 3,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 3,
#         Final count after deduplication: 3
#
# 'Fluconazole':
#         Initial count: 158,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 2,
#         Final count before deduplication: 156,
#         Final count after deduplication: 41
#
# 'Flucytosine':
#         Initial count: 19,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 19,
#         Final count after deduplication: 10
#
# 'Fludarabine Phosphate':
#         Initial count: 8,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 8,
#         Final count after deduplication: 7
#
# 'Flumazenil':
#         Initial count: 19,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 19,
#         Final count after deduplication: 10
#
# 'Fluorouracil':
#         Initial count: 37,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 37,
#         Final count after deduplication: 17
#
# 'Fluoxetine':
#         Initial count: 238,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 4,
#         Final count before deduplication: 234,
#         Final count after deduplication: 105
#
# 'Fluphenazine':
#         Initial count: 51,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 51,
#         Final count after deduplication: 33
#
# 'Flutamide':
#         Initial count: 2,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
# ...
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 21,
#         Final count after deduplication: 9
#
# 'Tamsulosin Hydrochloride':
#         Initial count: 113,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 6,
#         Final count before deduplication: 107,
#         Final count after deduplication: 46
#
# 'Tapentadol Hydrochloride':
#         Initial count: 10,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 10,
#         Final count after deduplication: 4
#
# 'Tasimelteon':
#         Initial count: 4,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 4,
#         Final count after deduplication: 4
#
# 'Tedizolid Phosphate':
#         Initial count: 2,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 2,
#         Final count after deduplication: 1
#
# 'Telmisartan':
#         Initial count: 53,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 14,
#         Final count before deduplication: 39,
#         Final count after deduplication: 16
#
# 'Telotristat Ethyl':
#         Initial count: 3,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 3,
#         Final count after deduplication: 1
#
# 'Temazepam':
#         Initial count: 87,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 87,
#         Final count after deduplication: 45
#
# 'Temozolomide':
#         Initial count: 13,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 13,
#         Final count after deduplication: 13
#
# 'Tenofovir Alafenamide Fumarate':
#         Initial count: 7,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 6,
#         Final count before deduplication: 1,
#         Final count after deduplication: 1
#
# 'Tenofovir Disoproxil Fumarate':
#         Initial count: 97,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 75,
#         Final count before deduplication: 22,
#         Final count after deduplication: 19
#
# 'Terazosin Hydrochloride':
#         Initial count: 56,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 56,
#         Final count after deduplication: 31
#
# 'Terbinafine Hydrochloride':
#         Initial count: 107,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 107,
#         Final count after deduplication: 49
#
# 'Terconazole':
#         Initial count: 22,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 22,
#         Final count after deduplication: 6
#
# 'Teriflunomide':
#         Initial count: 23,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 23,
#         Final count after deduplication: 20
#
# 'Tetrabenazine':
#         Initial count: 12,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 12,
#         Final count after deduplication: 11
#
# 'Thalidomide':
#         Initial count: 17,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 17,
#         Final count after deduplication: 14
#
# 'Thioguanine':
#         Initial count: 3,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 3,
#         Final count after deduplication: 1
#
# 'Thioridazine Hydrochloride':
#         Initial count: 3,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 3,
#         Final count after deduplication: 2
#
# 'Thiotepa':
#         Initial count: 14,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 14,
#         Final count after deduplication: 10
#
# 'Thiothixene':
#         Initial count: 7,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 7,
#         Final count after deduplication: 7
#
# 'Tiagabine Hydrochloride':
#         Initial count: 9,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 9,
#         Final count after deduplication: 6
#
# 'Timolol Maleate':
#         Initial count: 96,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 48,
#         Final count before deduplication: 48,
#         Final count after deduplication: 37
#
# 'Tinidazole':
#         Initial count: 10,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 10,
#         Final count after deduplication: 8
#
# 'Tiopronin':
#         Initial count: 5,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 5,
#         Final count after deduplication: 5
#
# 'Tirofiban Hydrochloride':
#         Initial count: 5,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 5,
#         Final count after deduplication: 4
#
# 'Tizanidine Hydrochloride':
#         Initial count: 158,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 158,
#         Final count after deduplication: 47
#
# 'Tofacitinib Citrate':
#         Initial count: 2,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 2,
#         Final count after deduplication: 2
#
# 'Tolcapone':
#         Initial count: 3,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 3,
#         Final count after deduplication: 3
#
# 'Tolterodine Tartrate':
#         Initial count: 31,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 31,
#         Final count after deduplication: 27
#
# 'Tolvaptan':
#         Initial count: 7,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 7,
#         Final count after deduplication: 7
#
# 'Topiramate':
#         Initial count: 217,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 1,
#         Final count before deduplication: 216,
#         Final count after deduplication: 97
#
# 'Toremifene Citrate':
#         Initial count: 4,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 4,
#         Final count after deduplication: 3
#
# 'Torsemide':
#         Initial count: 28,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 28,
#         Final count after deduplication: 17
#
# 'Tramadol Hydrochloride':
#         Initial count: 264,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 47,
#         Final count before deduplication: 217,
#         Final count after deduplication: 87
#
# 'Trametinib':
#         Initial count: 1,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 1,
#         Final count after deduplication: 1
#
# 'Tranexamic Acid':
#         Initial count: 46,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 3,
#         Final count before deduplication: 43,
#         Final count after deduplication: 18
#
# 'Tranylcypromine Sulfate':
#         Initial count: 9,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 9,
#         Final count after deduplication: 6
#
# 'Tranylcypromine':
#         Initial count: 9,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 9,
#         Final count after deduplication: 6
#
# 'Trazodone Hydrochloride':
#         Initial count: 140,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 140,
#         Final count after deduplication: 31
#
# 'Triamterene':
#         Initial count: 95,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 89,
#         Final count before deduplication: 6,
#         Final count after deduplication: 6
#
# 'Triazolam':
#         Initial count: 17,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 17,
#         Final count after deduplication: 11
#
# 'Trientine Hydrochloride':
#         Initial count: 16,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 16,
#         Final count after deduplication: 13
#
# 'Trientine':
#         Initial count: 17,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 17,
#         Final count after deduplication: 14
#
# 'Trifluoperazine Hydrochloride':
#         Initial count: 11,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 11,
#         Final count after deduplication: 5
#
# 'Trihexyphenidyl Hydrochloride':
#         Initial count: 21,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 21,
#         Final count after deduplication: 9
#
# 'Trimethobenzamide Hydrochloride':
#         Initial count: 14,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 14,
#         Final count after deduplication: 11
#
# 'Trimethoprim':
#         Initial count: 202,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 194,
#         Final count before deduplication: 8,
#         Final count after deduplication: 2
#
# 'Trimipramine Maleate':
#         Initial count: 6,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 6,
#         Final count after deduplication: 4
#
# 'Trospium Chloride':
#         Initial count: 23,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 23,
#         Final count after deduplication: 16
#
# 'Umeclidinium':
#         Initial count: 3,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 2,
#         Final count before deduplication: 1,
#         Final count after deduplication: 1
#
# 'Valacyclovir Hydrochloride':
#         Initial count: 113,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 113,
#         Final count after deduplication: 43
#
# 'Valganciclovir Hydrochloride':
#         Initial count: 28,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 28,
#         Final count after deduplication: 19
#
# 'Valproic Acid':
#         Initial count: 62,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 62,
#         Final count after deduplication: 28
#
# 'Valsartan':
#         Initial count: 185,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 104,
#         Final count before deduplication: 81,
#         Final count after deduplication: 57
#
# 'Vandetanib':
#         Initial count: 2,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 2,
#         Final count after deduplication: 2
#
# 'Vardenafil':
#         Initial count: 28,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 28,
#         Final count after deduplication: 14
#
# 'Varenicline Tartrate':
#         Initial count: 33,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 33,
#         Final count after deduplication: 22
#
# 'Venlafaxine Hydrochloride':
#         Initial count: 262,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 262,
#         Final count after deduplication: 118
#
# 'Verapamil Hydrochloride':
#         Initial count: 128,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 2,
#         Final count before deduplication: 126,
#         Final count after deduplication: 63
#
# 'Vigabatrin':
#         Initial count: 27,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 27,
#         Final count after deduplication: 21
#
# 'Vilazodone Hydrochloride':
#         Initial count: 13,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 13,
#         Final count after deduplication: 10
#
# 'Voriconazole':
#         Initial count: 40,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 40,
#         Final count after deduplication: 23
#
# 'Vorinostat':
#         Initial count: 1,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 1,
#         Final count after deduplication: 1
#
# 'Vortioxetine':
#         Initial count: 2,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 2,
#         Final count after deduplication: 2
#
# 'Warfarin Sodium':
#         Initial count: 121,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 121,
#         Final count after deduplication: 83
#
# 'Zafirlukast':
#         Initial count: 13,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 13,
#         Final count after deduplication: 10
#
# 'Zidovudine':
#         Initial count: 38,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 27,
#         Final count before deduplication: 11,
#         Final count after deduplication: 10
#
# 'Zileuton':
#         Initial count: 6,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 6,
#         Final count after deduplication: 5
#
# 'Ziprasidone Hydrochloride':
#         Initial count: 64,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 64,
#         Final count after deduplication: 28
#
# 'Zoledronic Acid':
#         Initial count: 35,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 35,
#         Final count after deduplication: 17
#
# 'Zolmitriptan':
#         Initial count: 34,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 34,
#         Final count after deduplication: 26
#
# 'Zolpidem Tartrate':
#         Initial count: 170,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 170,
#         Final count after deduplication: 62
#
# 'Zonisamide':
#         Initial count: 44,
#         Filtered for 'route_type': 0,
#         Filtered for 'actives': 0,
#         Final count before deduplication: 44,
#         Final count after deduplication: 28
#
#
# Total number of API-Excp mixture data entries for modeling: 21369

# %%
filtered_data['Zolmitriptan']
# Out:
# [{'actives': [('Zolmitriptan', '', '')],
#   'drug_name': 'ZOLMITRIPTAN tablet, orally disintegrating',
#   'inactives': [('Anhydrous Citric Acid', 'XF417D3PSL', '', ''),
#    ('Aspartame', 'Z0H242BBR1', '', ''),
#    ('Silicon Dioxide', 'ETJ7Z6XBU4', '', ''),
#    ('Gelatin', '2G86QN327L', '', ''),
#    ('Magnesium Stearate', '70097M6I30', '', ''),
#    ('Mannitol', '3OWL53L36A', '', ''),
#    ('Cellulose, Microcrystalline', 'OP1R32D61U', '', ''),
#    ('Orange', '5EVU04N5QU', '', ''),
#    ('Polacrilin Potassium', '0BZ5A00FQU', '', ''),
#    ('Sodium Stearyl Fumarate', '7CV7WJK4UI', '', ''),
#    ('Crospovidone', '2S7830E561', '', '')],
#   'route_type': 'ORAL'},
#  {'actives': [('Zolmitriptan', '', '')],
#   'drug_name': 'ZOLMITRIPTAN tablet, film coated',
#   'inactives': [('Anhydrous Lactose', '3SY5LH9PMK', '', ''),
#    ('Cellulose, Microcrystalline', 'OP1R32D61U', '', ''),
#    ('Sodium Starch Glycolate Type A Corn', 'AG9B65PV6B', '', ''),
#    ('Magnesium Stearate', '70097M6I30', '', ''),
#    ('Silicon Dioxide', 'ETJ7Z6XBU4', '', ''),
#    ('Titanium Dioxide', '15FIX9V2JP', '', ''),
#    ('Polyvinyl Alcohol, Unspecified', '532B59J990', '', ''),
#    ('Polyethylene Glycol, Unspecified', '3WJQ0SDW1A', '', ''),
#    ('Talc', '7SEV7J4R1U', '', ''),
#    ('Ferric Oxide Yellow', 'EX438O2MRT', '', '')],
#   'route_type': 'ORAL'},
#  {'actives': [('Zolmitriptan', '', '')],
#   'drug_name': 'ZOLMITRIPTAN tablet, film coated',
#   'inactives': [('Anhydrous Lactose', '3SY5LH9PMK', '', ''),
#    ('Microcrystalline Cellulose', 'OP1R32D61U', '', ''),
#    ('Sodium Starch Glycolate Type A Potato', '5856J3G2A2', '', ''),
#    ('Magnesium Stearate', '70097M6I30', '', ''),
#    ('Hypromellose, Unspecified', '3NXW29V3WO', '', ''),
#    ('Titanium Dioxide', '15FIX9V2JP', '', ''),
#    ('Polyethylene Glycol 4000', '4R4HFI6D95', '', ''),
#    ('Ferric Oxide Yellow', 'EX438O2MRT', '', '')],
#   'route_type': 'ORAL'},
#  {'actives': [('Zolmitriptan', '', '')],
#   'drug_name': 'ZOLMITRIPTAN tablet, film coated',
#   'inactives': [('Anhydrous Lactose', '3SY5LH9PMK', '', ''),
#    ('Cellulose, Microcrystalline', 'OP1R32D61U', '', ''),
#    ('Ferric Oxide Yellow', 'EX438O2MRT', '', ''),
#    ('Hypromellose, Unspecified', '3NXW29V3WO', '', ''),
#    ('Magnesium Stearate', '70097M6I30', '', ''),
#    ('Polyethylene Glycol 400', 'B697894SGQ', '', ''),
#    ('Silicon Dioxide', 'ETJ7Z6XBU4', '', ''),
#    ('Sodium Starch Glycolate Type A Potato', '5856J3G2A2', '', ''),
#    ('Titanium Dioxide', '15FIX9V2JP', '', '')],
#   'route_type': 'ORAL'},
#  {'actives': [('Zolmitriptan', '', '')],
#   'drug_name': 'ZOLMITRIPTAN tablet, orally disintegrating',
#   'inactives': [('Mannitol', '3OWL53L36A', '', ''),
#    ('Microcrystalline Cellulose', 'OP1R32D61U', '', ''),
#    ('Crospovidone (120 .Mu.M)', '68401960MK', '', ''),
#    ('Silicon Dioxide', 'ETJ7Z6XBU4', '', ''),
#    ('Aspartame', 'Z0H242BBR1', '', ''),
#    ('Sodium Stearyl Fumarate', '7CV7WJK4UI', '', ''),
#    ('Magnesium Stearate', '70097M6I30', '', ''),
#    ('Triacetin', 'XHX3C3X673', '', ''),
#    ('Orange', '5EVU04N5QU', '', '')],
#   'route_type': 'ORAL'},
#  {'actives': [('Zolmitriptan', '', '')],
#   'drug_name': 'ZOLMITRIPTAN- zolmitriptan tablet, film coated',
#   'inactives': [('Cellulose, Microcrystalline', 'OP1R32D61U', '', ''),
#    ('Anhydrous Lactose', '3SY5LH9PMK', '', ''),
#    ('Sodium Starch Glycolate Type A Potato', '5856J3G2A2', '', ''),
#    ('Magnesium Stearate', '70097M6I30', '', ''),
#    ('
'', '')],
#   'route_type': 'ORAL'},
#  {'actives': [('Zolmitriptan', '', '')],
#   'drug_name': 'ZOLMITRIPTAN tablet, film coated',
#   'inactives': [('Anhydrous Lactose', '3SY5LH9PMK', '', ''),
#    ('Silicon Dioxide', 'ETJ7Z6XBU4', '', ''),
#    ('Hypromellose 2910 (6 Mpa.S)', '0WZ8WG20P6', '', ''),
#    ('Magnesium Stearate', '70097M6I30', '', ''),
#    ('Microcrystalline Cellulose', 'OP1R32D61U', '', ''),
#    ('Polyethylene Glycol 4000', '4R4HFI6D95', '', ''),
#    ('Sodium Starch Glycolate Type A Potato', '5856J3G2A2', '', ''),
#    ('Titanium Dioxide', '15FIX9V2JP', '', ''),
#    ('Ferric Oxide Yellow', 'EX438O2MRT', '', '')],
#   'route_type': 'ORAL'},
#  {'actives': [('Zolmitriptan', '', '')],
#   'drug_name': 'ZOMIG- zolmitriptan tabletZOMIG ZMT- zolmitriptan tablet, orally disintegrating',
#   'inactives': [('Anhydrous Lactose', '3SY5LH9PMK', '', ''),
#    ('Microcrystalline Cellulose', 'OP1R32D61U', '', ''),
#    ('Sodium Starch Glycolate Type A Potato', '5856J3G2A2', '', ''),
#    ('Magnesium Stearate', '70097M6I30', '', ''),
#    ('Hydroxypropyl Cellulose (1600000 Wamw)', 'RFW2ET671P', '', ''),
#    ('Titanium Dioxide', '15FIX9V2JP', '', ''),
#    ('Polyethylene Glycol 400', 'B697894SGQ', '', ''),
#    ('Polyethylene Glycol 8000', 'Q662QK8M3B', '', ''),
#    ('Ferric Oxide Yellow', 'EX438O2MRT', '', ''),
#    ('Water', '059QF0KO0R', '', '')],
#   'route_type': 'ORAL'},
#  {'actives': [('Zolmitriptan', '', '')],
#   'drug_name': 'ZOLMITRIPTAN spray, metered',
#   'inactives': [('Anhydrous Citric Acid', 'XF417D3PSL', '', ''),
#    ('Nitrogen', 'N762921K75', '', ''),
#    ('Sodium Phosphate, Dibasic, Unspecified Form', 'GR686LBA74', '', ''),
#    ('Water', '059QF0KO0R', '', '')],
#   'route_type': 'NASAL'},
#  {'actives': [('Zolmitriptan', '', '')],
#   'drug_name': 'ZOLMITRIPTAN spray',
#   'inactives': [('Anhydrous Citric Acid', 'XF417D3PSL', '', ''),
#    ('Sodium Phosphate, Dibasic, Dodecahydrate', 'E1W4N241FO', '', ''),
#    ('Water', '059QF0KO0R', '', ''),
#    ('Benzalkonium Chloride', 'F5UM2KM3W7', '', '')],
#   'route_type': 'NASAL'},
#  {'actives': [('Zolmitriptan', '', '')],
#   'drug_name': 'ZOLMITRIPTAN tablet, film coated',
#   'inactives': [('Lactose Monohydrate', 'EWQ57Q8I5X', '', ''),
#    ('Cellulose, Microcrystalline', 'OP1R32D61U', '', ''),
#    ('Sodium Starch Glycolate Type A Potato', '5856J3G2A2', '', ''),
#    ('Magnesium Stearate', '70097M6I30', '', ''),
#    ('Hypromellose 2910 (10000 Mpa.S)', '0HO1H52958', '', ''),
#    ('Polyethylene Glycol 1000', 'U076Q6Q621', '', ''),
#    ('Polysorbate 80', '6OZP39ZG8H', '', ''),
#    ('Titanium Dioxide', '15FIX9V2JP', '', ''),
#    ('Ferric Oxide Yellow', 'EX438O2MRT', '', '')],
#   'route_type': 'ORAL'},
#  {'actives': [('Zolmitriptan', '', '')],
#   'drug_name': 'ZOLMITRIPTAN OD- zolmitriptan tablet, orally disintegrating',
#   'inactives': [('Magnesium Aluminometasilicate Type I-A',
#     '7LVU907546',
#     '',
#     ''),
#    ('Silicon Dioxide', 'ETJ7Z6XBU4', '', ''),
#    ('Sodium Lauryl Sulfate', '368GB5141J', '', ''),
#    ('Hydroxypropyl Cellulose, Low Substituted', '2165RE0K14', '', ''),
#    ('Dimethylaminoethyl Methacrylate - Butyl Methacrylate - Methyl Methacrylate Copolymer',
#     '905HNO1SIH',
#     '',
#     ''),
#    ('Talc', '7SEV7J4R1U', '', ''),
#    ('Mannitol', '3OWL53L36A', '', ''),
#    ('Crospovidone, Unspecified', '2S7830E561', '', ''),
#    ('Acesulfame Potassium', '23OV73Q5G9', '', ''),
#    ('Magnesium Stearate', '70097M6I30', '', ''),
#    ('Peppermint', 'V95R5KMY2B', '', '')],
#   'route_type': 'ORAL'},
#  {'actives': [('Zolmitriptan', '', '')],
#   'drug_name': 'ZOMIG- zolmitriptan tablet',
#   'inactives': [('Anhydrous Lactose', '3SY5LH9PMK', '', ''),
#    ('Cellulose, Microcrystalline', 'OP1R32D61U', '', ''),
#    ('Sodium Starch Glycolate Type A Potato', '5856J3G2A2', '', ''),
#    ('Magnesium Stearate', '70097M6I30', '', ''),
#    ('Hydroxypropyl Cellulose', 'RFW2ET671P', '', ''),
#    ('Titanium Dioxide', '15FIX9V2JP', '', ''),
#    ('Polyethylene Glycol 400', 'B697894SGQ', '', ''),
#    ('Polyethylene Glycol 8000', 'Q662QK8M3B', '', ''),
#    ('Ferric Oxide Red', '1K09F3G675', '', '')],
#   'route_type': 'ORAL'},
#  {'actives': [('Zolmitriptan', '', '')],
#   'drug_name': 'ZOLMIPTRIPTAN- zolmitriptan tablet, orally disintegrating',
#   'inactives': [('Mannitol', '3OWL53L36A', '', ''),
#    ('Microcrystalline Cellulose', 'OP1R32D61U', '', ''),
#    ('Crospovidone (120 .Mu.M)', '68401960MK', '', ''),
#    ('Aspartame', 'Z0H242BBR1', '', ''),
#    ('Silicon Dioxide', 'ETJ7Z6XBU4', '', ''),
#    ('Talc', '7SEV7J4R1U', '', ''),
#    ('Magnesium Stearate', '70097M6I30', '', ''),
#    ('Starch, Corn', 'O8232NY3SJ', '', '')],
#   'route_type': 'ORAL'},
#  {'actives': [('Zolmitriptan', '', '')],
#   'drug_name': 'ZOMIG- zolmitriptan spray, metered',
#   'inactives': [('Citric Acid Anhydrous', 'XF417D3PSL', '', ''),
#    ('Sodium Phosphate, Dibasic', 'GR686LBA74', '', ''),
#    ('Water', '059QF0KO0R', '', ''),
#    ('Nitrogen', 'N762921K75', '', '')],
#   'route_type': 'NASAL'}]

# %%
unique_chems = {
    'inactive_unii': set(),
    'inactive_name': set(),
    'active_name': set()
}

for items in filtered_data.values():
    for entry in items:
        unique_chems['active_name'].update([active[0] for active in entry['actives']])
        unique_chems['inactive_unii'].update([inactive[1] for inactive in entry['inactives'] if inactive[1]])
        unique_chems['inactive_name'].update([inactive[0] for inactive in entry['inactives'] if not inactive[1]])

unique_chems = {key: list(value) for key, value in unique_chems.items()}

# %%
# Grab SMILES (canonical or isometric -- RDKit Chem.MolFromSmiles can take both)

# pubchem(UNII) --> SMILES
    # Need a step to handle when not found 
import requests
import time

def get_smiles_from_unii(unii_codes):
    base_url = "https://pubchem.ncbi.nlm.nih.gov/rest/pug"
    smiles_dict = {}
    delay = 0.2  # Start with a default delay of 200ms between requests

    for unii in unii_codes:
        time.sleep(delay)  # Respect the delay before making a request
        url = f"{base_url}/compound/name/{unii}/property/CanonicalSMILES/JSON"
        
        response = requests.get(url)
        
        # Check for throttling headers and adjust delay
        if 'X-Throttling-Control' in response.headers:
            throttling_header = response.headers['X-Throttling-Control']
            print(f"Throttling status: {throttling_header}")  # Optional: print the throttling status for debugging
            if "Red" in throttling_header or "Black" in throttling_header:
                delay = 1  # Increase delay to 1 second if in Red or Black status
            elif "Yellow" in throttling_header:
                delay = 0.5  # Increase delay to 500ms if in Yellow status
            else:
                delay = 0.2  # Otherwise, reset to the default delay

        if response.status_code == 200:
            data = response.json()
            smiles = data['PropertyTable']['Properties'][0]['CanonicalSMILES']
            smiles_dict[unii] = smiles
        elif response.status_code == 503:
            print(f"Request limit exceeded for UNII: {unii}. Retrying with increased delay.")
            time.sleep(delay)  # Wait before retrying
            continue  # Optionally, you can implement retry logic here
        else:
            print(f"Could not fetch data for UNII: {unii}")
            smiles_dict[unii] = None

    return smiles_dict


############ MARCH 25

#### Model development usihng existing one to one data

#### Data cleaning
## Do another pass of using OpenFDA
## Another pass for Names with ChemResolver
## Filter all found items
## Model
############


# pubchem(standardized name (inactive and active)) --> SMILES
    # Standardize Names
    
from fuzzywuzzy import process, fuzz
import pandas as pd
import requests
import time

def standardize_names(names_list):
    return [name.replace(" ()", "").strip().lower() for name in names_list]


# def resolve_chemical_name(names_list):
#     resolved_names = {}
#     base_url = "https://cactus.nci.nih.gov/chemical/structure"
#     for name in names_list:
#         url = f"{base_url}/{name}/names"
#         try:
#             response = requests.get(url)
#             if response.status_code == 200 and response.text:
#                 # Take the first resolved name as the canonical name
#                 canonical_name = response.text.split('\n')[0].lower()
#                 if canonical_name in resolved_names:
#                     resolved_names[canonical_name].append(name)
#                 else:
#                     resolved_names[canonical_name] = [name]
#             else:
#                 # If the name isn't found, create a key with an empty list
#                 resolved_names[name] = []
#         except Exception as e:
#             print(f"Error resolving name {name}: {e}")
#             resolved_names[name] = []
#     return resolved_names


import requests
import time

def resolve_chemical_name(names_list, retries=2, backoff_factor=1):
    resolved_names = {}
    base_url = "https://cactus.nci.nih.gov/chemical/structure"
    error_counter = 0  # Keep track of consecutive errors

    for name in names_list:
        url = f"{base_url}/{name}/names"
        attempt = 0
        while attempt < retries:
            try:
                response = requests.get(url)
                if response.status_code == 200 and response.text:
                    canonical_name = response.text.split('\n')[0].lower()
                    resolved_names[canonical_name] = resolved_names.get(canonical_name, []) + [name]
                    error_counter = 0  # Reset error counter on success
                    break  # Successful resolution, break out of the retry loop
                elif response.status_code == 500:
                    # Don't retry if a chemical doesn't exist (server returns 500)
                    resolved_names[name] = []
                    error_counter = 0  # Reset error counter
                    break
                elif response.status_code == 429 or response.status_code >= 502:
                    # Handle rate limiting and server errors
                    print(f"Server error for {name}, will retry after delay...")
                    error_counter += 1
                    time.sleep(backoff_factor * (2 ** attempt))  # Exponential backoff
                    attempt += 1
                else:
                    # For other client-side errors, don't retry
                    resolved_names[name] = []
                    break
            except requests.exceptions.RequestException as e:
                print(f"Request exception for {name}: {e}")
                error_counter += 1
                time.sleep(backoff_factor * (2 ** attempt))
                attempt += 1

            # Check if we're approaching the error limit
            if error_counter >= 25:  # Conservative approach to avoid hitting the limit
                print("Approaching server error limit, pausing...")
                time.sleep(180)  # Pause for 3 minutes to reset server's error count
                error_counter = 0

        if attempt == retries:
            print(f"Failed to resolve after {retries} attempts: {name}")
            resolved_names[name] = []

    return resolved_names


def combine_similar_names(resolved_names_dict, threshold=90):
    combined_names = {}
    keys_checked = set()

    for name in resolved_names_dict.keys():
        if name in keys_checked:
            continue
        similar_names = [key for key in resolved_names_dict.keys() if fuzz.ratio(name, key) >= threshold and key not in keys_checked]
        
        combined_list = []
        for similar_name in similar_names:
            combined_list.extend(resolved_names_dict[similar_name])
            keys_checked.add(similar_name)
        
        if similar_names:
            combined_names[similar_names[0]] = combined_list
        else:
            combined_names[name] = resolved_names_dict[name]

    return combined_names

#     # Deduplicate (similar using Fuzz)
# def deduplicate_names(names_list, threshold=90):
#     unique_names = {}
#     for name in names_list:
#         if not unique_names:  # If unique_names is empty, add the first name directly.
#             unique_names[name] = [name]
#             continue

#         match = process.extractOne(name, list(unique_names.keys()), scorer=fuzz.partial_ratio)
#         if match:
#             best_match, score = match
#             if score >= threshold:
#                 unique_names[best_match].append(name)
#             else:
#                 unique_names[name] = [name]
#         else:
#             unique_names[name] = [name]
    
#     # Select a representative for each group (e.g., the most common name)
#     representative_names = [names[0] for names in unique_names.values()]
#     return unique_names

#     # Name to SMILES
# def get_smiles_from_names(names):
#     base_url = "https://pubchem.ncbi.nlm.nih.gov/rest/pug"
#     smiles_dict = {}

#     for name in names:
#         url = f"{base_url}/compound/name/{name}/property/CanonicalSMILES/JSON"
#         response = requests.get(url)
#         if response.status_code == 200:
#             data = response.json()
#             smiles = data['PropertyTable']['Properties'][0]['CanonicalSMILES']
#             smiles_dict[name]= smiles
#         else:
#             smiles_dict[name] = None

#     return smiles_dict

# %%
unii_to_smiles = get_smiles_from_unii(unique_chems['inactive_unii'])
# Out:
# Throttling status: Request Count status: Green (0%), Request Time status: Green (0%), Service status: Green (23%)
# Throttling status: Request Count status: Green (0%), Request Time status: Green (0%), Service status: Green (40%)
# Could not fetch data for UNII: W2ZU1RY8B0
# Throttling status: Request Count status: Green (1%), Request Time status: Green (0%), Service status: Green (27%)
# Throttling status: Request Count status: Green (1%), Request Time status: Green (0%), Service status: Green (37%)
# Could not fetch data for UNII: HZ58M6D839
# Throttling status: Request Count status: Green (0%), Request Time status: Green (0%), Service status: Green (23%)
# Could not fetch data for UNII: 724GKU717M
# Throttling status: Request Count status: Green (1%), Request Time status: Green (0%), Service status: Green (30%)
# Throttling status: Request Count status: Green (0%), Request Time status: Green (0%), Service status: Green (17%)
# Could not fetch data for UNII: T91K54D6M1
# Throttling status: Request Count status: Green (1%), Request Time status: Green (0%), Service status: Green (27%)
# Could not fetch data for UNII: 3S5ITS5ULN
# Throttling status: Request Count status: Green (1%), Request Time status: Green (0%), Service status: Green (20%)
# Throttling status: Request Count status: Green (1%), Request Time status: Green (0%), Service status: Green (27%)
# Could not fetch data for UNII: ANA2NCS6V1
# Throttling status: Request Count status: Green (2%), Request Time status: Green (0%), Service status: Green (10%)
# Throttling status: Request Count status: Green (1%), Request Time status: Green (0%), Service status: Green (33%)
# Could not fetch data for UNII: 0243Q4990L
# Throttling status: Request Count status: Green (1%), Request Time status: Green (0%), Service status: Green (40%)
# Could not fetch data for UNII: WVK1CT5994
# Throttling status: Request Count status: Green (2%), Request Time status: Green (0%), Service status: Green (40%)
# Throttling status: Request Count status: Green (2%), Request Time status: Green (0%), Service status: Green (13%)
# Throttling status: Request Count status: Green (2%), Request Time status: Green (0%), Service status: Green (40%)
# Could not fetch data for UNII: 32766B2FHX
# Throttling status: Request Count status: Green (2%), Request Time status: Green (0%), Service status: Green (30%)
# Throttling status: Request Count status: Green (3%), Request Time status: Green (0%), Service status: Green (27%)
# Could not fetch data for UNII: REK4960K2U
# Throttling status: Request Count status: Green (3%), Request Time status: Green (0%), Service status: Green (37%)
# Throttling status: Request Count status: Green (3%), Request Time status: Green (0%), Service status: Green (37%)
# Throttling status: Request Count status: Green (3%), Request Time status: Green (0%), Service status: Green (30%)
# Throttling status: Request Count status: Green (2%), Request Time status: Green (0%), Service status: Green (33%)
# Could not fetch data for UNII: 236QY0A1BL
# Throttling status: Request Count status: Green (4%), Request Time status: Green (0%), Service status: Green (47%)
# Could not fetch data for UNII: 8NSU66JGZR
)
# Throttling status: Request Count status: Green (14%), Request Time status: Green (1%), Service status: Green (23%)
# Could not fetch data for UNII: 9755T40D11
# Throttling status: Request Count status: Green (19%), Request Time status: Green (1%), Service status: Green (27%)
# Could not fetch data for UNII: XR6BC2ZUAM
# Throttling status: Request Count status: Green (14%), Request Time status: Green (1%), Service status: Green (37%)
# Throttling status: Request Count status: Green (14%), Request Time status: Green (1%), Service status: Green (37%)
# Could not fetch data for UNII: 1BEM3U6LQQ
# Throttling status: Request Count status: Green (14%), Request Time status: Green (1%), Service status: Green (20%)
# Throttling status: Request Count status: Green (18%), Request Time status: Green (1%), Service status: Green (40%)
# Could not fetch data for UNII: I9GRO824LL
# Throttling status: Request Count status: Green (15%), Request Time status: Green (1%), Service status: Green (33%)
# Throttling status: Request Count status: Green (15%), Request Time status: Green (1%), Service status: Green (23%)
# Could not fetch data for UNII: W00LYS4T26
# Throttling status: Request Count status: Green (15%), Request Time status: Green (1%), Service status: Green (33%)
# Throttling status: Request Count status: Green (15%), Request Time status: Green (1%), Service status: Green (27%)
# Throttling status: Request Count status: Green (15%), Request Time status: Green (1%), Service status: Green (27%)
# Throttling status: Request Count status: Green (16%), Request Time status: Green (1%), Service status: Green (30%)
# Throttling status: Request Count status: Green (16%), Request Time status: Green (1%), Service status: Green (37%)

# %%
round(100*len([key for key, val in unii_to_smiles.items() if val]) / len(unii_to_smiles), 2)
# Out:
# 44.18

# %%
names = standardize_names(unique_chems['active_name']+unique_chems['inactive_name'])

# %%
# TODO - Need to determine the rate request limit
resolvedd_chemical_names = resolve_chemical_name(names[:30])

# %%
resolvedd_chemical_names
# Out:
# {'4-[(3-chloro-4-methoxyphenyl)methylamino]-2-[(2s)-2-(hydroxymethyl)pyrrolidin-1-yl]-n-(pyrimidin-2-ylmethyl)pyrimidine-5-carboxamide': ['avanafil'],
#  '(1s,4s)-4-(3,4-dichlorophenyl)-n-methyl-1,2,3,4-tetrahydronaphthalen-1-amine hydrochloride': ['sertraline hydrochloride'],
#  'gadolinium cation (3+)': [],
#  'n-[(4-hydroxy-3-methoxyphenyl)methyl]-8-methylnon-6-enamide': ['capsaicin'],
#  'methyl 2-phenyl-2-piperidin-2-ylacetate': ['methylphenidate'],
#  '(4s)-6-chloro-4-(2-cyclopropylethynyl)-4-(trifluoromethyl)-1h-3,1-benzoxazin-2-one': ['efavirenz'],
#  '5-[2-(benzenesulfonyl)ethyl]-3-[[(2r)-1-methylpyrrolidin-2-yl]methyl]-1h-indole hydrobromide': ['eletriptan hydrobromide'],
#  '2-(6-methoxynaphthalen-2-yl)propanoic acid': ['naproxen'],
#  '2-[di(phenyl)methoxy]-n,n-dimethylethanamine': ['diphenhydramine'],
#  'methyl 7-[(1r,2r,3r)-3-hydroxy-2-[(e)-4-hydroxy-4-methyloct-1-enyl]-5-oxocyclopentyl]heptanoate': ['misoprostol'],
#  '4-[2-(tert-butylamino)-1-hydroxyethyl]-2-(hydroxymethyl)phenol': ['albuterol'],
#  '1,4-dihydroxy-5,8-bis[2-(2-hydroxyethylamino)ethylamino]anthracene-9,10-dione': ['mitoxantrone'],
#  '(e)-n,6,6-trimethyl-n-(naphthalen-1-ylmethyl)hept-2-en-4-yn-1-amine hydrochloride': ['terbinafine hydrochloride'],
#  '(2s)-1-[(2s)-2-methyl-3-sulfanylpropanoyl]pyrrolidine-2-carboxylic acid': ['captopril'],
#  '(2r,3r)-2,3-dihydroxybutanedioic acid; 2-[(1s)-3-(di(propan-2-yl)amino)-1-phenylpropyl]-4-methylphenol': ['tolterodine tartrate'],
#  '2-(3,4-dimethoxyphenyl)-5-[2-(3,4-dimethoxyphenyl)ethyl-methylamino]-2-propan-2-ylpentanenitrile hydrochloride': ['verapamil hydrochloride'],
#  '6,7-dichloro-5,10-dihydro-3h-imidazo[2,1-b]quinazolin-2-one': ['anagrelide'],
#  '2-(2,6-dioxopiperidin-3-yl)isoindole-1,3-dione': ['thalidomide'],
#  '(3-carbamoyloxy-2-phenylpropyl) carbamate': ['felbamate'],
#  '[(3s)-oxolan-3-yl] n-[(2s,3r)-4-[(4-aminophenyl)sulfonyl-(2-methylpropyl)amino]-1-phenyl-3-phosphonooxybutan-2-yl]carbamate': ['fosamprenavir'],
#  'thioguanine': [],
#  '2-(2-chlorophenyl)-2-methylaminocyclohexan-1-one': ['ketamine'],
#  'propan-2-yl 2-[4-(4-chlorobenzoyl)phenoxy]-2-methylpropanoate': ['fenofibrate'],
#  '[5-(6-amino-2-fluoropurin-9-yl)-3,4-dihydroxyoxolan-2-yl]methyl dihydrogen phosphate': ['fludarabine phosphate'],
#  '8-chloro-1-methyl-6-phenyl-4h-[1,2,4]triazolo[4,3-a][1,4]benzodiazepine': ['alprazolam'],
#  '(6r)-6-methylamino-6,7,8,9-tetrahydro-5h-carbazole-3-carboxamide': ['frovatriptan'],
#  '2-hydroxy-5-[1-hydroxy-2-(4-phenylbutan-2-ylamino)ethyl]benzamide': ['labetalol'],
#  '7-(1,2,3,4,4a,5,7,7a-octahydropyrrolo[3,4-b]pyridin-6-yl)-1-cyclopropyl-6-fluoro-8-methoxy-4-oxoquinoline-3-carboxylic acid hydrochloride': ['moxifloxacin hydrochloride'],
#  '[2-[(8s,9s,10r,11s,13s,14s,17r)-11,17-dihydroxy-10,13-dimethyl-3-oxo-2,6,7,8,9,11,12,14,15,16-decahydro-1h-cyclopenta[a]phenanthren-17-yl]-2-oxoethyl] acetate': ['hydrocortisone acetate'],
#  'o-naphthalen-2-yl [methyl-(3-methylphenyl)amino]methanethioate': ['tolnaftate']}

# %%
# ## Next step is to get the mol2vec and 2D descriptors for each unique active + inactive
# unique_chemicals = {chem[0] for items in filtered_data.values() for item in items for chem in (item.get('actives', []) + item.get('inactives', [])) if chem}

# # Convert the set to a sorted list
# unique_chemical_names = sorted(unique_chemicals)

# %%
## UNII GRAB AS WELL
## Remove special characters prior to running through UNII grab for SMILES
len(unique_chemical_names)
# Out:
# 2734

# %%
[
    [
        active: [mol2vec, 2d]
        inactivates [[mol2vec, 2d],[],]
        conditions [pH, density, ...]
    ]
    
    
    
    

]

# %%
## Research 2D -- 
## Research negative data for chemical mixtures

# %%
import cv2
import numpy as np

# Load your image
image_path = '/Users/samueljon/Downloads/test_frame.png'  # replace with your image path
image = cv2.imread(image_path)

# Check if image was loaded
if image is None:
    print("Error: Could not load image.")
else:
    # Define your line coordinates
    x1, y1 = 78, 337
    x2, y2 = 229, 66

    # Create a line on the image
    color = (0, 255, 0)  # Line color (B, G, R)
    thickness = 2  # Line thickness
    cv2.line(image, (x1, y1), (x2, y2), color, thickness)

    # Save the image with the line
    save_path = '/Users/samueljon/Downloads/test_frame_wCV2Line.png'  # replace with your save path
    cv2.imwrite(save_path, image)
